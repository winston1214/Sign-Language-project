# %% [markdown]
# ## Environment Settings

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# !pip3 install torch==1.2.0
# !pip3 install torchvision==0.4.0
# Out:
# Collecting torch==1.2.0
#   Downloading torch-1.2.0-cp37-cp37m-manylinux1_x86_64.whl (748.9 MB)
#      |████████████████████████████████| 748.9 MB 597 bytes/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torch==1.2.0) (1.19.5)
# Installing collected packages: torch
#   Attempting uninstall: torch
#     Found existing installation: torch 1.10.0+cu111
#     Uninstalling torch-1.10.0+cu111:
#       Successfully uninstalled torch-1.10.0+cu111
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchvision 0.11.1+cu111 requires torch==1.10.0, but you have torch 1.2.0 which is incompatible.
# torchtext 0.11.0 requires torch==1.10.0, but you have torch 1.2.0 which is incompatible.
# torchaudio 0.10.0+cu111 requires torch==1.10.0, but you have torch 1.2.0 which is incompatible.
# Successfully installed torch-1.2.0
# Collecting torchvision==0.4.0
#   Downloading torchvision-0.4.0-cp37-cp37m-manylinux1_x86_64.whl (8.8 MB)
#      |████████████████████████████████| 8.8 MB 4.7 MB/s
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from torchvision==0.4.0) (1.15.0)
# Requirement already satisfied: torch==1.2.0 in /usr/local/lib/python3.7/dist-packages (from torchvision==0.4.0) (1.2.0)
# Requirement already satisfied: pillow>=4.1.1 in /usr/local/lib/python3.7/dist-packages (from torchvision==0.4.0) (7.1.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torchvision==0.4.0) (1.19.5)
# Installing collected packages: torchvision
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.11.1+cu111
#     Uninstalling torchvision-0.11.1+cu111:
#       Successfully uninstalled torchvision-0.11.1+cu111
# Successfully installed torchvision-0.4.0

# %%
import os
import numpy as np
import json
import pandas as pd
import torch.nn.functional as F
import re
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical
import torch
import torch.nn as nn
import torchvision
import torchvision.transforms as transforms
import torch.backends.cudnn as cudnn
import random

torch.manual_seed(0)
torch.cuda.manual_seed(0)
torch.cuda.manual_seed_all(0)
np.random.seed(0)
cudnn.benchmark = False
cudnn.deterministic = True
random.seed(0)

# Device Settings
device = torch.device('cuda' if torch.cuda.is_available else 'cpu')
print('device : ', device)
# Out:
# device :  cuda

# %%
print("Torch version:{}".format(torch.__version__))
print("Torchvision version:{}".format(torchvision.__version__))
# Out:
# Torch version:1.2.0
# Torchvision version:0.4.0

# %% [markdown]
# # Data Load & Preprocessing

# %% [markdown]
# Alphapose Keypoint Data Load

# %%
cd '/content/drive/MyDrive/BOAZ_수어프로젝트/Data/pickle'
# Out:
# /content/drive/MyDrive/BOAZ_수어프로젝트/Data/pickle

# %%
ls
# Out:
# 30593_32029_X.pickle  X_test.pickle  X_train.pickle

# %%
import gzip
import pickle

# %%
with gzip.open('X_train.pickle','rb') as f:
  X_train = pickle.load(f)

# %%
X_train.shape # (비디오 개수, frame 개수, keypoint 개수)
# Out:
# (7129, 376, 246)

# %%
X_data = X_train

# %% [markdown]
# Target Word Data Load

# %%
import pandas as pd

target = pd.read_csv('/content/drive/MyDrive/BOAZ_수어프로젝트/Data/train_target.excel')

# %%
target1 = target[(target['num'] <= 35620) & (target['num'] >= 30593)]
target2 = target[(target['num'] <= 42131) & (target['num'] >= 40028)]
target = target1.append(target2)
drop_idx = target.loc[(target['num']== 41098) | (target['num'] == 41106) | (target['num'] == 41108)].index
target.drop(drop_idx,axis=0,inplace=True)

# %%
target.shape
# Out:
# (7129, 2)

# %%
target['target']
# Out:
# 20112                             0
# 20113                             1
# 20114                             2
# 20115                             3
# 20116                             4
#                     ...
# 31646    술 취한 사람이 방망이로 사람들을 때리고 있어요
# 31647                     집에 불이 났어요
# 31648              집에 도둑(강도)이 들어왔어요
# 31649             어떤 사람이 교통사고를 당했어요
# 31650           식사를 하다가 목에 음식이 걸렸어요
# Name: target, Length: 7129, dtype: object

# %%
# for i in range(len(target)):
#   target['target'][i]=str(target['target'][i])

target= target['target']
target
# 단어 target에서 기호같은거 제거해주는 등의 전처리 필요할 것으로 생각됨 !!!!
# Out:
# 20112                             0
# 20113                             1
# 20114                             2
# 20115                             3
# 20116                             4
#                     ...
# 31646    술 취한 사람이 방망이로 사람들을 때리고 있어요
# 31647                     집에 불이 났어요
# 31648              집에 도둑(강도)이 들어왔어요
# 31649             어떤 사람이 교통사고를 당했어요
# 31650           식사를 하다가 목에 음식이 걸렸어요
# Name: target, Length: 7129, dtype: object

# %%
# 부가적으로 필요없는 문자들 제거해주기
target=target.map(lambda x: re.sub('[(-,)=.#/?:$}]','', x))

# %% [markdown]
# '-' 같은 기호 띄어쓰기로 대체

# %%
# 시작 구분기호로 \t를 끝 구분기호로 \n을 추가해줌
target = target.apply(lambda x : 's '+ x + ' f')

# %% [markdown]
# Target data preprocessing

# %%
# 글자 집합 구축
tar_vocab = set()
for line in target:
  tar_vocab.add(line)

# %%
temp = []
for line in target:
  temp.append(line)

# %%
temp[-1:]
# Out:
# ['s 식사를 하다가 목에 음식이 걸렸어요 f']

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
from nltk.tokenize import word_tokenize
# [('s', 7129), ('f', 7129), ('사람이', 380), ('있어요', 259), ('어떤', 240), ('같아요', 200), ('났어요', 161), ('불이', 141), ('것', 140), ('갑자기', 120), ('집에', 102), ('친구가', 80), ('아이가', 80), ('당했어요', 61), ('몸이', 60), ('끼었어요', 60), ('삼켰어요', 60), ('아기가', 60), ('저를', 60), ('있는', 60), ('안', 60), ('갇혔어요', 60), ('많이', 60), ('모르는', 60), ('불러주세요', 60), ('밖에', 60), ('감전', 52), ('하다가', 41), ('집이', 40), ('멈췄어요', 40), ('해안가에', 40), ('나타났어요', 40), ('폭탄이', 40), ('터졌어요', 40), ('쓰러지셨어요', 40), ('쓰러졌어요', 40), ('장난감을', 40), ('음식을', 40), ('숨을', 40), ('나고', 40), ('피를', 40), ('흘리고', 40), ('못', 40), ('쏘였어요', 40), ('가스가', 40), ('새고', 40), ('해요', 40), ('도와주세요', 40), ('아이를', 40), ('심해요', 40), ('아파서', 40), ('빨리', 40), ('방에', 40), ('수', 40), ('없어요', 40), ('칼에', 40), ('강아지가', 39), ('산에서', 39), ('물렸어요', 39), ('옆집', 36), ('119', 32), ('결박', 32), ('무릎', 32), ('병원', 32), ('서대문구', 32), ('집', 32), ('아저씨', 24), ('할아버지', 24), ('유치원', 24), ('도둑강도이', 21), ('들어왔어요', 21), ('교통사고를', 21), ('식사를', 21), ('목에', 21), ('음식이', 21), ('걸렸어요', 21), ('홍수가', 20), ('나서', 20), ('물에', 20), ('잠기고', 20), ('엘리베이터가', 20), ('중간에', 20), ('자살을', 20), ('시도하고', 20), ('바다에', 20), ('빠졌어요', 20), ('상어가', 20), ('해파리가', 20), ('주변', 20), ('구조물이', 20), ('무너져서', 20), ('몸을', 20), ('움직이지', 20), ('못하겠어요', 20), ('근처에서', 20), ('할머니가', 20), ('뼈를', 20), ('사켰어요', 20), ('고속도로에서', 20), ('자동차가', 20), ('배가', 20), ('침몰하고', 20), ('이상한', 20), ('쫓아와요', 20), ('쫓아오는', 20), ('무기흉기를', 20), ('소지하고', 20), ('근처에', 20), ('건물이', 20), ('붕괴되고', 20), ('지하철', 20), ('역', 20), ('안에서', 20), ('화재가', 20), ('발생했어요', 20), ('화상을', 20), ('입었어요', 20), ('먹다가', 20), ('실수로', 20), ('방부제를', 20), ('같이', 20), ('먹었어요', 20), ('사고를', 20), ('쉬는', 20), ('사람한테', 20), ('납치당했어요', 20), ('광견병에', 20), ('걸린', 20), ('개에게', 20), ('건물에서', 20), ('추락했어요', 20), ('눈에', 20), ('이물질이', 20), ('들어갔어요', 20), ('터널이', 20), ('무너져', 20), ('어디선가', 20), ('연기가', 20), ('나요', 20), ('급류에', 20), ('휩쓸렸어요', 20), ('비행기가', 20), ('추락하고', 20), ('길거리에서', 20), ('스키를', 20), ('타다가', 20), ('넘어져서', 20), ('일어나겠어요', 20), ('말벌에게', 20), ('해파리에게', 20), ('독버섯을', 20), ('먹은', 20), ('신체부위가', 20), ('절단됐어요', 20), ('바다에서', 20), ('조난을', 20), ('벼락을', 20), ('맞았어요', 20), ('문에', 20), ('고압선이', 20), ('끊어져', 20), ('숨이', 20), ('쉬어져요', 20), ('당해있어요', 20), ('죽이려고', 20), ('!', 20), ('야생동물을', 20), ('만났어요', 20), ('공격할', 20), ('우리', 20), ('윗집에', 20), ('옆집에', 20), ('아랫집에', 20), ('사고가', 20), ('침입했어요', 20), ('강도가', 20), ('들어온것', 20), ('아기를', 20), ('낳을것', 20), ('토해요', 20), ('쉬어요', 20), ('공원에서', 20), ('잃어버렸어요', 20), ('데려갔어요', 20), ('독극물을', 20), ('복통이', 20), ('참을것', 20), ('내가', 20), ('흔들려요', 20), ('벽이', 20), ('무너질려고', 20), ('유리가', 20), ('깨져서', 20), ('발을', 20), ('다쳤어요', 20), ('남편이', 20), ('높은데서', 20), ('떨어져서', 20), ('머리에서', 20), ('피나요', 20), ('무거운', 20), ('물건에', 20), ('깔렸어요', 20), ('몸에', 20), ('열이', 20), ('두통이', 20), ('세브란스', 20), ('진료', 20), ('예약을', 20), ('해주세요', 20), ('우리아이가', 20), ('의식을', 20), ('잃었어요', 20), ('구조대를', 20), ('어지러워서', 20), ('서있을', 20), ('소방차를', 20), ('서성거려요', 20), ('112에', 20), ('신고해주세요', 20), ('싸움이', 20), ('경찰을', 20), ('아내가', 20), ('아들이', 20), ('놀이터에서', 20), ('놀다가', 20), ('팔이', 20), ('부러졌어요', 20), ('발목을', 20), ('접질렀어요', 20), ('전기가', 20), ('나갔어요', 20), ('손가락을', 20), ('베였어요', 20), ('허리가', 20), ('일어날', 20), ('찔려서', 20), ('말벌에', 20), ('쏘여서', 20), ('기절했어요', 20), ('인대를', 20), ('다친', 20), ('엄마가', 20), ('신장병에', 20), ('있는데', 20), ('여기', 20), ('홍제동', 20), ('한양아파트인데', 20), ('옥상에서', 20), ('떨어지려고해요', 20), ('동생이', 20), ('문틈에', 20), ('손이', 20), ('너무', 20), ('아파요', 20), ('와주세요', 20), ('칼로', 20), ('위협하고', 20), ('술', 20), ('취한', 20), ('방망이로', 20), ('사람들을', 20), ('때리고', 20), ('집단폭력을', 19), ('당하고', 19), ('차', 19), ('안에', 19), ('방치되어있어요', 19), ('뱀에게', 19), ('0', 12), ('1', 12), ('2', 12), ('3', 12), ('4', 12), ('5', 12), ('6', 12), ('7', 12), ('8', 12), ('9', 12), ('10', 12), ('11', 12), ('12', 12), ('13', 12), ('14', 12), ('15', 12), ('16', 12), ('17', 12), ('18', 12), ('19', 12), ('20', 12), ('21', 12), ('22', 12), ('23', 12), ('24', 12), ('25', 12), ('26', 12), ('27', 12), ('28', 12), ('29', 12), ('30', 12), ('31', 12), ('32', 12), ('33', 12), ...

# %%
word_to_index = {}

for i, (word, frequency) in enumerate(vocab_sorted):
  word_to_index[word] = i

print(word_to_index)
# Out:
# {'s': 0, 'f': 1, '사람이': 2, '있어요': 3, '어떤': 4, '같아요': 5, '났어요': 6, '불이': 7, '것': 8, '갑자기': 9, '집에': 10, '친구가': 11, '아이가': 12, '당했어요': 13, '몸이': 14, '끼었어요': 15, '삼켰어요': 16, '아기가': 17, '저를': 18, '있는': 19, '안': 20, '갇혔어요': 21, '많이': 22, '모르는': 23, '불러주세요': 24, '밖에': 25, '감전': 26, '하다가': 27, '집이': 28, '멈췄어요': 29, '해안가에
0, 485, 1], [0, 486, 1], [0, 487, 1], [0, 488, 1], [0, 489, 1], [0, 490, 1], [0, 491, 1], [0, 492, 1], [0, 493, 1], [0, 494, 1], [0, 495, 1], [0, 63, 1], [0, 496, 1], [0, 497, 1], [0, 498, 1], [0, 499, 1], [0, 500, 1], [0, 501, 1], [0, 502, 1], [0, 503, 1], [0, 504, 1], [0, 505, 1], [0, 506, 1], [0, 507, 1], [0, 508, 1], [0, 509, 1], [0, 510, 1], [0, 511, 1], [0, 512, 1], [0, 513, 1], [0, 64, 1], [0, 514, 1], [0, 515, 1], [0, 516, 1], [0, 517, 1], [0, 518, 1], [0, 519, 1], [0, 520, 1], [0, 521, 1], [0, 522, 1], [0, 523, 1], [0, 524, 1], [0, 525, 1], [0, 526, 1], [0, 527, 1], [0, 528, 1], [0, 529, 1], [0, 530, 1], [0, 531, 1], [0, 532, 533, 1], [0, 534, 1], [0, 535, 1], [0, 536, 1], [0, 537, 1], [0, 538, 1], [0, 539, 1], [0, 540, 1], [0, 541, 1], [0, 542, 1], [0, 543, 1], [0, 66, 1], [0, 544, 1], [0, 545, 1], [0, 546, 1], [0, 547, 1], [0, 548, 1], [0, 549, 1], [0, 550, 1], [0, 551, 1], [0, 552, 1], [0, 553, 1], [0, 554, 1], [0, 555, 1], [0, 556, 1], [0, 557, 1], [0, 558, 1], [0, 559, 1], [0, 560, 1], [0, 561, 1], [0, 562, 1], [0, 563, 1], [0, 564, 1], [0, 565, 1], [0, 566, 1], [0, 567, 1], [0, 568, 1], [0, 569, 1], [0, 59, 1] ...

# %%
max_tar_len = max([len(line) for line in temp])
print(max_tar_len)
# Out:
# 40

# %%
decoder_input = pad_sequences(encoded_sentences, maxlen=max_tar_len, padding='post')
decoder_input.shape
# Out:
# (7129, 40)

# %%
X_train= torch.tensor(X_train)
decoder_input = torch.LongTensor(decoder_input)

# %%
decoder_Input= decoder_input

# %%
X_train = X_data[:6000]
X_valid = X_data[6000:7000]
X_test = X_data[7000:]

decoder_input = decoder_Input[:6000]
decoder_input_valid = decoder_Input[6000:7000]
decoder_input_test = decoder_Input[7000:]

# %%
X_train = torch.tensor(X_train)
X_valid = torch.tensor(X_valid)
X_test = torch.tensor(X_test)

decoder_input = torch.tensor(decoder_input, dtype=torch.long)
decoder_input_valid = torch.tensor(decoder_input_valid, dtype=torch.long)
decoer_input_test = torch.tensor(decoder_input_test, dtype=torch.long)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   """
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   import sys

# %% [markdown]
# Dataloader

# %%
from torch.utils.data import TensorDataset, DataLoader

train_dataset = TensorDataset(X_train, decoder_input)
valid_dataset = TensorDataset(X_valid, decoder_input_valid)

# %%
train_dataloader = DataLoader(train_dataset,batch_size= 32,shuffle= True) # create your dataloader
valid_dataloader = DataLoader(valid_dataset,batch_size= 32,shuffle= True)# create your dataloader

# %%
for i, (keypoints, labels) in enumerate(train_dataloader):
    print(i)
    print(keypoints.shape)
    print(labels.shape)
    if i ==2:
      break
# Out:
# 0
# torch.Size([32, 376, 246])
# torch.Size([32, 40])
# 1
# torch.Size([32, 376, 246])
# torch.Size([32, 40])
# 2
# torch.Size([32, 376, 246])
# torch.Size([32, 40])

# %% [markdown]
# 따라서 input data가 (batch_size, frame수, keypoint개수)로 변경됨
# target data는 (batch_size, embedding_matrix(12개로 padding한 단어를 128차원으로 임베딩)

# %% [markdown]
# # Modeling seq2seq

# %% [markdown]
# Encoder

# %%
# Encoder 정의하기 

class Encoder(nn.Module):
    def __init__(self, input_size, hid_dim, n_layers):
        super().__init__() 
        self.hid_dim = hid_dim
        self.n_layers = n_layers
        # batch_first = True
        self.gru = nn.GRU(input_size, hid_dim, n_layers, batch_first = True, bidirectional = True)
        self.fc = nn.Linear(hid_dim*2, hid_dim)
        # input_size = keypoint 개수

    def forward(self, x): 
        # input x : (BATCH, LENGTH, INPUT_SIZE)임  (다양한 length를 다룰 수 있습니다.).
        # 최초의 hidden state와 cell state를 초기화
        
        # x = ([16, 81, 246])
        # h0 = (2, batch, 512)
        h0 = torch.zeros(self.n_layers*2, x.size(0), self.hid_dim).to(device).float()

        # hidden = [n layers * n directions, batch size, hid dim]
        # cell = [n layer * n directions, batch size, hid dim]
        # print(h0.shape) # torch.Size([2, 2, 512])
        # LSTM 순전파
        out, hidden = self.gru(x, h0)
        #print(hidden.shape)
        hidden = torch.tanh(self.fc(torch.cat((hidden[-2,:,:], hidden[-1,:,:]), dim = 1)))
    
        # print(out.shape) # torch.Size([2, 227, 1024]) = batch, frame, hidden*2

        # output : (BATCH_SIZE, SEQ_LENGTH, HIDDEN_SIZE) tensors. 
        return out, hidden

# %% [markdown]
# Attention

# %%
class Attention(nn.Module):
    def __init__(self, hid_dim):
        super().__init__()
        
        self.attn = nn.Linear((hid_dim * 2) + hid_dim, hid_dim)
        self.v = nn.Linear(hid_dim, 1, bias = False)
        
    def forward(self, hidden, encoder_outputs):
        
        #hidden = [batch size, dec hid dim]
        #encoder_outputs = [src len, batch size, enc hid dim * 2]
        
        # hidden = (2, batch, hid_dim) 
        # output =  batch, frame, hidden*2

        batch_size = encoder_outputs.shape[0]
        src_len = encoder_outputs.shape[1]
        # print(hidden.shape) # torch.Size([2, 512])


        #repeat decoder hidden state src_len times
        hidden = hidden.unsqueeze(1).repeat(1, src_len, 1)
        
        
        
        #hidden = [batch size, src len, dec hid dim]
        #encoder_outputs = [batch size, src len, enc hid dim * 2]
        # print(hidden.shape)
        # print(encoder_outputs.shape)

        energy = torch.tanh(self.attn(torch.cat((hidden, encoder_outputs), dim = 2))) 
        
        #energy = [batch size, src len, dec hid dim]

        attention = self.v(energy).squeeze(2)
        
        #attention= [batch size, src len]
        
        return F.softmax(attention, dim=1)

# %% [markdown]
# Decoder

# %%
class Decoder(nn.Module):
    def __init__(self, output_dim,  emb_dim, hid_dim, n_layers, attention,dropout):
        super().__init__() 

        # output_dim = len(TRG.vocab) softmax로 총 단어 집합 중 어떤 단어인지 선택

        self.output_dim = output_dim
        self.hid_dim = hid_dim
        self.attention = attention
        self.n_layers = n_layers
        self.embedding = nn.Embedding(output_dim, emb_dim)

        self.gru = nn.GRU(hid_dim*2+emb_dim, hid_dim)
        self.fc_out = nn.Linear((hid_dim*2)+hid_dim+emb_dim, output_dim)
        self.dropout = nn.Dropout(dropout)
        

    def forward(self, input, hidden, encoder_outputs): 

        # LSTM 순전파
        # input = [16]
        input = input.unsqueeze(0)  # 1,16
        embedded = self.dropout(self.embedding(input)) # 1, 16, 128

        attention = self.attention(hidden, encoder_outputs)
        attention = attention.unsqueeze(1)
        
        #encoder_outputs = [batch size, src len, enc hid dim * 2]

        weighted = torch.bmm(attention, encoder_outputs)
        # print('weighted.shape :', weighted.shape) # weighted.shape : torch.Size([2, 1, 1024])
        #weighted = [batch size, 1, enc hid dim * 2]
        
        weighted = weighted.permute(1, 0, 2)
        
        #weighted = [1, batch size, enc hid dim * 2]
        
        rnn_input = torch.cat((embedded, weighted), dim = 2)
        # print('rnn_input shape: ' , rnn_input.shape) # rnn_input shape:  torch.Size([1, 2, 1152])
        # print('hidden.shape: ', hidden.shape) # hidden.shape:  torch.Size([2, 512])


        out1, hidden = self.gru(rnn_input, hidden.unsqueeze(0)) # # hidden.shape:  torch.Size([1, 2, 512])


        assert (out1 == hidden).all()
        
        embedded = embedded.squeeze(0)
        out1 = out1.squeeze(0)
        weighted = weighted.squeeze(0)
        
        prediction = self.fc_out(torch.cat((out1, weighted, embedded), dim = 1))
 

        # 마지막 time step(sequence length)의 hidden state를 사용해 Class들의 logit을 반환합니다(hid_dim -> num_classes). 
        #out1 = self.fc(out1[:, -1, :])
        
        return prediction,hidden.squeeze(0)

# %% [markdown]
# seq2seq

# %%
import random
class Seq2Seq(nn.Module):

    def __init__(self, encoder, decoder, device):
        super().__init__()
        
        self.encoder = encoder
        self.decoder = decoder
        self.device = device
        
        assert encoder.hid_dim == decoder.hid_dim, \
            "Hidden dimensions of encoder and decoder must be equal!"
        assert encoder.n_layers == decoder.n_layers, \
            "Encoder and decoder must have equal number of layers!"
        
    def forward(self, src, trg, teacher_forcing_ratio = 0.8):
        
    
        batch_size = trg.shape[0] # 16 batch_size
        trg_len = trg.shape[1] #12 padding
        trg_vocab_size = self.decoder.output_dim

        # output을 저장할 tensor를 만들기.(처음에는 전부 0으로)
        outputs = torch.zeros(trg_len, batch_size,trg_vocab_size).to(self.device)

        encoder_outputs, hidden = self.encoder(src)
        # outputs = (12(padding), 16(batch), 단어사전의 총 단어개수)
        # src문장을 encoder에 넣은 후 hidden, cell값을 구합니다.

        
        
        # decoder에 입력할 첫번째 input입니다.
        # 첫번째 input은 모두 <sos> token입니다.
        # trg[0,:].shape = BATCH_SIZE 

        # 첫번째인풋은 vocab 모음 중에서 /t를 인코딩한 부분 !!
        input = trg[:,0]

        '''한번에 batch_size만큼의 token들을 독립적으로 계산 -> 즉 frame개수 만큼 Batch 설정??
        즉, 총 trg_len번의 for문이 돌아가며 이 for문이 다 돌아가야지만 하나의 문장이(지금은 단어가) decoding됨
        또한, 1번의 for문당 128개의 문장의 각 token들이 다같이 decoding되는 것'''
        for t in range(1, trg_len): # range(1, 12) -> 12는 단어 하나의 길이를 padding

            #trg_len = 12
            # input token embedding과 이전 hidde state를 decoder에 입력합니다.
            # 새로운 hidde states와 예측 output값이 출력됩니다.

            output, hidden = self.decoder(input, hidden, encoder_outputs)
            #이때 output은 final_state = out1[:,-1,:], prediction = self.fc_out(final_state) 
            #output = [batch_size, output dim] prediction 은?:  torch.Size([1, 341])
            # 각각의 출력값을 outputs tensor에 저장합니다.
            outputs[t] = output
            # outputs = (12(padding), 16(batch), 단어사전의 총 단어개수)
            
            teacher_force = random.random() < teacher_forcing_ratio
      
            # top1 = [batch size]
            top1 = output.argmax(1)

            # teacher forcing기법을 사용한다면, 다음 input으로 target을 입력하고
            # 아니라면 이전 state의 예측된 출력값을 다음 input으로 사용합니다.

            input = trg[:,t] if teacher_force else top1

        return outputs

# %% [markdown]
# Parameter & Optimizer

# %%
input_size = 246 # keypoint vector 길이
HID_DIM = 512
OUTPUT_DIM = len(vocab)+1
N_LAYERS = 2
DEC_DROPOUT = 0.5
emb_dim = 128


enc = Encoder(input_size, HID_DIM, N_LAYERS)
att = Attention(HID_DIM)
dec = Decoder(OUTPUT_DIM, emb_dim, HID_DIM, N_LAYERS, att, DEC_DROPOUT)

model = Seq2Seq(enc, dec, device).to(device)

# %%
def init_weights(m):
    for name, param in m.named_parameters():
        nn.init.uniform_(param.data, -0.08, 0.08)
        
model.apply(init_weights)
# Out:
# Seq2Seq(
#   (encoder): Encoder(
#     (gru): GRU(246, 512, num_layers=2, batch_first=True, bidirectional=True)
#     (fc): Linear(in_features=1024, out_features=512, bias=True)
#   )
#   (decoder): Decoder(
#     (attention): Attention(
#       (attn): Linear(in_features=1536, out_features=512, bias=True)
#       (v): Linear(in_features=512, out_features=1, bias=False)
#     )
#     (embedding): Embedding(677, 128)
#     (gru): GRU(1152, 512)
#     (fc_out): Linear(in_features=1664, out_features=677, bias=True)
#     (dropout): Dropout(p=0.5, inplace=False)
#   )
# )

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

print(f'The model has {count_parameters(model):,} trainable parameters')
# Out:
# The model has 12,144,549 trainable parameters

# %%
optimizer = torch.optim.Adam(model.parameters())
criterion = nn.CrossEntropyLoss()

# %% [markdown]
# ## Train and Validation

# %%
def train(model, train_dataloader, optimizer, criterion, clip):
    
    model.train()
    
    epoch_loss = 0
   
    for i, (input, target) in enumerate(train_dataloader):

        src = input
        trg = target

        if torch.cuda.is_available():
          model.cuda()
          src = src.cuda().float()
          trg = trg.cuda()
       
        # src = [16, 81, 246] batch, frame수, keypoint수
        # trg(trg)= [16, 12] = batch, trg_len

        optimizer.zero_grad()        
        
        output = model(src, trg)
        #trg = [trg len, batch size] [16,12]
        #output = [trg len, batch size, output dim]
        
        output = output[1:].view(-1, OUTPUT_DIM)
        trg = torch.transpose(trg,0,1)
        trg = trg[1:].contiguous().view(-1)
              
        #trg = [(trg len - 1) * batch size]
        #output = [(trg len - 1) * batch size, output dim]
        loss = criterion(output, trg)
        
        loss.backward()
        
        torch.nn.utils.clip_grad_norm_(model.parameters(), clip)
        
        optimizer.step()
        
        epoch_loss += loss.item()
        
    return epoch_loss / len(train_dataloader)

# %%
def evaluate(model, valid_dataloader, criterion):
    
    model.eval()
    
    epoch_loss = 0
    
    with torch.no_grad():
   
      for i,(input, target) in enumerate(valid_dataloader): # valid_dataloader 정의하기
          src = input
          trg = target

          if torch.cuda.is_available():
            model.cuda()
            src = src.cuda().float()
            trg = trg.cuda()

          output = model(src, trg, 0)
          #trg = [trg len, batch size] [16,12]
          #output = [trg len, batch size, output dim]
          
          output = output[1:].view(-1, OUTPUT_DIM)
          trg = torch.transpose(trg,0,1)
          trg = trg[1:].contiguous().view(-1)
                
          #trg = [(trg len - 1) * batch size]
          #output = [(trg len - 1) * batch size, output dim]
          loss = criterion(output, trg)
          
          epoch_loss += loss.item()
          
      return epoch_loss / len(valid_dataloader)

# %%
# trg_indexes = [word_to_index['s']]
# a = torch.LongTensor([trg_indexes[-1]]).to(device)
# a
# Out:
# tensor([0], device='cuda:0')

# %%
def translate_SL(src, word_to_index, model, device, max_len = 81):
  '''
  src: 번역하고자 하는 keypoint
  word_to_index: korean index 뭉치
  '''

  model.eval()

  # sign_language = "<sos>" + sign_language + "<eos>"
  # print(f"sign language: {sign_language}")
  # 인덱스 파트 (변수명: src_tensor)

  with torch.no_grad():

    encoder_outputs, hidden = model.encoder(src)
  
  trg_indexes = [word_to_index['s']] # [0]
  end_index = word_to_index['f']
  
  for i in range(max_len): #max_len = 81
    # trg_tensor = torch.LongTensor([trg_indexes[-1]]).to(device)
    trg_tensor = torch.tensor([trg_indexes[-1]],dtype=torch.long).to(device) # tensor([0])

    with torch.no_grad():
        output, hidden= model.decoder(trg_tensor, hidden, encoder_outputs)

    pred_token = output.argmax(1).item()

    if pred_token == end_index:
      break
      
    trg_indexes.append(pred_token) # 출력 문장에 더하기
    # # <eos>를 만나는 순간 끝
    # 각 출력 단어 인덱스를 실제 단어로 변환
    # trg_tokens = [trg_field.vocab.itos[i] for i in trg_indexes]
    # trg_tokens = [word_to_index[i] for i in trg_indexes]
  trg_tokens = [list(word_to_index)[i] for i in trg_indexes]
    # trg_tokens = [key for key, value in word_to_index.items() if value == i]


    # 첫 번째 <sos>는 제외하고 출력 문장 반환
  return trg_tokens[1:]

# %%
def BLEU_Evaluate(model,dataloader,criterion, word_to_index,OUTPUT_DIM , device, max_len = 81):
    '''
    src: 번역하고자 하는 keypoint
    word_to_index: korean index 뭉치
    '''
    zero_pred = 0
    model.eval()
    epoch_loss = 0
    BLEU = 0
    acc = 0
    cnt = 0
    for _,(input, target) in enumerate(dataloader): 
        
        src = input
        trg = target

        if torch.cuda.is_available():
            model.cuda()
            src = src.cuda().float()

            trg = trg.cuda()
            trg2 = trg

        with torch.no_grad(): # evaluation
            
            # hidden, cell = model.encoder(src)
            output = model(src,trg,0) # evaluate
            output = output[1:].view(-1,OUTPUT_DIM) # evaluate
            trg = torch.transpose(trg,0,1) # evaluate
            trg = trg[1:].contiguous().view(-1) # evaluate

            loss = criterion(output,trg) # evaluate
            epoch_loss += loss.item() # evaluate
        
        for input_data,target in zip(src,trg2):
            input_data = torch.unsqueeze(input_data, 0)
            cnt += 1
            ref = []
            for t in target:
                if t == 1:
                    break
                else:
                    ref.append(list(word_to_index)[t])
            ref = ' '.join(ref)
            
            candidate = ' '.join(translate_SL(input_data, word_to_index, model, device,max_len))
            ref = re.sub('[sf]','',ref)
            ref = ref.strip()
            print(candidate)
            print(ref)
            if len(candidate.split()) == 0:
                zero_pred += 1
            else:
                BLEU += bleu.sentence_bleu([ref.split()], candidate.split(),weights = [1,0,0,0])
                acc += sum(x == y for x, y in zip(ref.split(), candidate.split())) / len(candidate.split())
            if cnt == zero_pred:
                BLEU , acc = 0
            else:
                BLEU = BLEU / (cnt - zero_pred)
                acc = acc/(cnt - zero_pred)
    # 첫 번째 <sos>는 제외하고 출력 문장 반환
    return epoch_loss / len(dataloader), BLEU, acc

# %%
def epoch_time(start_time, end_time):
    elapsed_time = end_time - start_time
    elapsed_mins = int(elapsed_time / 60)
    elapsed_secs = int(elapsed_time - (elapsed_mins * 60))
    return elapsed_mins, elapsed_secs

# %%
from tqdm.notebook import tqdm
import time

import gc
gc.collect()
torch.cuda.empty_cache()

# %%
import nltk.translate.bleu_score as bleu
import math

# %%
best_valid_loss = float('inf')
BLEU_ls = []
train_loss_ls = []
N_EPOCHS = 30
val_loss_ls = []
max_len = 81
acc_ls = []
epoch_ls = [i for i in range(N_EPOCHS)]
model_save_path = './'
save_model_name = 'model1.pt'
CLIP = 1
    
for epoch in tqdm(range(N_EPOCHS)):
    start_time = time.time()

    train_loss = train(model, train_dataloader, optimizer, criterion, CLIP)
    valid_loss, BLEU,acc = BLEU_Evaluate(model,valid_dataloader,criterion, word_to_index, OUTPUT_DIM, device, max_len=81)

    train_loss_ls.append(train_loss)
    val_loss_ls.append(valid_loss)
    BLEU_ls.append(BLEU)
    acc_ls.append(acc)
    # valid_loss = evaluate(model, val_dataloader, OUTPUT_DIM,criterion)

    end_time = time.time()
    epoch_mins, epoch_secs = epoch_time(start_time, end_time)

    if valid_loss < best_valid_loss:
        best_valid_loss = valid_loss
        torch.save(model.state_dict(), f'{model_save_path}{save_model_name}')
    
    print(f'Epoch: {epoch + 1:02} | Time: {epoch_mins}m {epoch_secs}s')
    print(f'\t Train Loss: {train_loss:.3f} | Train PPL: {math.exp(train_loss):7.3f}')
    print(f'\t Val Loss: {valid_loss:.3f} | Val PPL: {math.exp(valid_loss):7.3f}')
    print(f'\t Val BLEU : {BLEU : .3f} | Val Accuracy : {acc : .3f}')
# Out:
#   0%|          | 0/30 [00:00<?, ?it/s]
# 알려주세요
# 유리가 깨져서 발을 다쳤어요
# 진통제
# 어떤 사람이 집단폭력을 당하고 있어요
# 산에서 야생동물을 만났어요 저를 공격할 것 같아요
# 산에서 야생동물을 만났어요 저를 공격할 것 같아요
# 아내가 쓰러졌어요
# 아내가 쓰러졌어요
# 끓는물
# 음식을 하다가 손가락을 칼에 베였어요
# 성동구
# 집에 전기가 나갔어요
# 말벌에게 쏘였어요
# 사람이 갑자기 쓰러졌어요
# /usr/local/lib/python3.7/dist-packages/nltk/translate/bleu_score.py:490: UserWarning:
# Corpus/Sentence contains 0 counts of 3-gram overlaps.
# BLEU scores might be undesirable; use SmoothingFunction().
#   warnings.warn(_msg)
# 식사를 하다가 목에 음식이 걸렸어요
# 식사를 하다가 목에 음식이 걸렸어요
# 산에서 뱀에게 물렸어요
# 친구가 숨을 안 쉬는 것 같아요
# 어떤 사람이 교통사고를 당했어요
# 어떤 사람이 교통사고를 당했어요
# 깔리다
# 사람이 무거운 물건에 깔렸어요
# 집에 불이 났어요
# 윗집에 불이 났어요
# 진통제
# 어떤 사람이 자살을 시도하고 있어요
# 어떤 사람이 자살을 시도하고 있어요
# 어떤 사람한테 납치당했어요
# /usr/local/lib/python3.7/dist-packages/nltk/translate/bleu_score.py:490: UserWarning:
# Corpus/Sentence contains 0 counts of 2-gram overlaps.
# BLEU scores might be undesirable; use SmoothingFunction().
#   warnings.warn(_msg)
# /usr/local/lib/python3.7/dist-packages/nltk/translate/bleu_score.py:490: UserWarning:
# Corpus/Sentence contains 0 counts of 4-gram overlaps.
# BLEU scores might be undesirable; use SmoothingFunction().
#   warnings.warn(_msg)
# 근처에 있는 건물이 붕괴되고 있어요
# 근처에 있는 건물이 붕괴되고 있어요
# 어떤 사람이 자살을 시도하고 있어요
# 어떤 사람이 칼에 찔려서 피를 많이 흘리고 있어요
# 진통제
# 어떤 사람이 교통사고를 당했어요
# 아기를 낳을것 같아요
# 아기를 낳을것 같아요
# 운동장
# 아기가 숨을 안 쉬어요
# 아이가 방에 갇혔어요
# 터널이 무너져 갇혔어요
# 보내주세요구급차
# 엄마가 신장병에 있는데 쓰러지셨어요
# 진통제
# 어떤 사람이 자살을 시도하고 있어요
# 해안가에 상어가 나타났어요
# 어떤 사람이 저를 죽이려고 해요
# 결박 방에 갇혔어요
# 아이가 방에 갇혔어요
# 보내주세요구급차
# 엄마가 신장병에 있는데 쓰러지셨어요
# 해안가에 상어가 나타났어요
# 해안가에 상어가 나타났어요
# 아기를 낳을것 같아요
# 아기를 낳을것 같아요
# 집에 불이 났어요
# 윗집에 불이 났어요
# 말벌에게 쏘였어요
# 아이가 말벌에 쏘여서 기절했어요
# 왼쪽-눈
# 문에 몸이 끼었어요
# 성북구
# 집이 흔들려요
# 말벌에게 쏘였어요
# 어지러워서 서있을 수 없어요
# 산에서 뱀에게 물렸어요
# 아랫집에 불이 났어요
# 독극물
# 아파서 못 참을것 같아요
# 말벌에게 쏘였어요
# 말벌에게 쏘였어요
# 골절
# 친구가 감전 사고를 당했어요
# 진통제
# 산에서 뱀에게 물렸어요
# 진통제
# 동생이 문틈에 손이 끼었어요
# 식사를 하다가 목에 음식이 걸렸어요
# 식사를 하다가 목에 음식이 걸렸어요
# 허리가 연기가 나요 s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s
# 쫓아오는 것 같아요
# 성북구
# 옆집에 불이 났어요
# 터널이 무너져 갇혔어요
# 터널이 무너져 갇혔어요
# 성동구
# 문에 몸이 끼었어요
# 산에서 입었어요
# 화상을 입었어요
# 아이를 모르는 사람이 데려갔어요
# 아이를 모르는 사람이 데려갔어요
# 산에서 뱀에게 물렸어요
# 지하철 역 안에서 화재가 발생했어요
# 보내주세요구급차
# 세브란스 병원 진료 예약을 해주세요
# 보내주세요구급차
# 이상한 사람이 저를 쫓아와요
# 화요일
# 숨이 안 쉬어져요
# 아기를 낳을것 같아요
# 우리아이가 갑자기 의식을 잃었어요
# 운동장
# 아기가 갑자기 토해요
# 진통제
# 어떤 사람이 자살을 시도하고 있어요
# 복통
# 복통이 심해요
# 119
# 112에 신고해주세요
# 독극물
# 어떤 사람이 길거리에서 피를 많이 흘리고 있어요
# 어떤 사람이 무기흉기를 소지하고 있어요
# 어떤 사람이 저를 죽이려고 해요
# 아기를 낳을것 같아요
# 집 벽이 무너질려고 해요
# 어디선가 연기가 나요 불이 나고 있는 것 같아요
# 어떤 사람이 저를 죽이려고 해요
# 허리가 연기가 나요 불이 나고 있는 것 같아요
# 강아지가 뼈를 삼켰어요
# 아기를 낳을것 같아요
# 집 벽이 무너질려고 해요
# 경찰
# 해안가에 상어가 나타났어요
# 연기
# 쫓아오는 것 같아요
# 성동구
# 폭탄이 터졌어요
# 독극물
# 숨이 안 쉬어져요
# 도와주세요 !
# 도와주세요 !
# 해안가에 상어가 나타났어요
# 해안가에 해파리가 나타났어요
# 운동장
# 아기가 숨을 안 쉬어요
# 우리집
# 우리 집에 불이 났어요
# 무릎 인대를 다친 것 같아요
# 무릎 인대를 다친 것 같아요
# 엘리베이터
# 밖에 불이 났어요 소방차를 불러주세요
# 장단지
# 발목을 접질렀어요
# 터널이 방에 갇혔어요
# 사람이 무거운 물건에 깔렸어요
# 집에 도둑강도이 들어왔어요
# 집에 도둑강도이 들어왔어요
# 말벌에게 쏘였어요
# 어지러워서 서있을 수 없어요
# 고압전선
# 어떤 사람이 건물에서 추락했어요
# 보내주세요구급차
# 할머니가 갑자기 쓰러지셨어요
# 아이가 장난감을 삼켰어요
# 아이가 장난감을 삼켰어요
# 스키를 타다가 넘어져서 못 일어나겠어요
# 스키를 타다가 넘어져서 못 일어나겠어요
# 강북구
# 해파리에게 쏘였어요
# 가스가 새고 있는 것 같아요
# 가스가 새고 있는 것 같아요
# 아이가 장난감을 삼켰어요
# 아이가 장난감을 삼켰어요
# 아파트
# 친구가 숨을 안 쉬는 것 같아요
# 칼
# 친구가 감전 사고를 당했어요
# 학생
# 신체부위가 절단됐어요
# 깔리다
# 우리 집에 불이 났어요
# 산에서 뱀에게 물렸어요
# 아랫집에 불이 났어요
# 알려주세요
# 윗집에 불이 났어요
# 중랑구
# 옆집에 불이 났어요
# 독극물
# 눈에 이물질이 들어갔어요
# 장단지
# 발목을 접질렀어요
# 급류에 친구가 휩쓸렸어요
# 급류에 친구가 휩쓸렸어요
# 고압전선
# 폭탄이 터졌어요
# 터널이 무너져 갇혔어요
# 터널이 무너져 갇혔어요
# 강아지가 뼈를 삼켰어요
# 강아지가 뼈를 삼켰어요
# 차안
# 차 안에 강아지가 방치되어있어요
# 아들이 놀이터에서 놀다가 팔이 부러졌어요
# 아들이 놀이터에서 놀다가 팔이 부러졌어요
# 열
# 밖에 불이 났어요 소방차를 불러주세요
# 통학버스
# 근처에 있는 건물이 붕괴되고 있어요
# 우리아이가 갑자기 의식을 잃었어요
# 우리아이가 갑자기 의식을 잃었어요
# 칼
# 빨리 도와주세요
# 빨리 와주세요
# 빨리 와주세요
# 아이가 장난감을 삼켰어요
# 아이가 장난감을 삼켰어요
# 아이를 공원에서 잃어버렸어요
# 아이를 공원에서 잃어버렸어요
# 해안가에 상어가 나타났어요
# 해안가에 상어가 나타났어요
# 몸에 열이 많이 나고 두통이 심해요
# 몸에 열이 많이 나고 두통이 심해요
# 어디선가 연기가 나요 불이 나고 있는 것 같아요
# 어떤 사람이 벼락을 맞았어요
# 아이가
# 여기 서대문구 홍제동 한양아파트인데 옥상에서 사람이 떨어지려고해요
# 말벌에게 쏘였어요
# 말벌에게 쏘였어요
# 성북구
# 집이 흔들려요
# 경찰
# 비행기가 추락하고 있어요
# 운동장
# 아기가 숨을 안 쉬어요
# 기절하다
# 광견병에 걸린 개에게 물렸어요
# 바다에서 조난을 당했어요
# 바다에서 조난을 당했어요
# 반점생기다
# 세브란스 병원 진료 예약을 해주세요
# 아이를 모르는 사람이 데려갔어요
# 아이를 모르는 사람이 데려갔어요
# 아이가 장난감을 삼켰어요
# 아기가 장난감을 사켰어요
# 복통
# 너무 아파요
# 발작
# 광견병에 걸린 개에게 물렸어요
# 집에 불이 났어요
# 아랫집에 불이 났어요
# 허리가 아파요
# 어떤 사람이 저를 죽이려고 해요
# 산에서 뱀에게 물렸어요
# 감전 사고가 났어요
# 어떤 사람이 건물에서 추락했어요
# 어떤 사람이 건물에서 추락했어요
# 끓는물
# 바다에서 조난을 당했어요
# 아이를 공원에서 손가락을 칼에 베였어요
# 바다에서 조난을 당했어요
# 반점생기다
# 세브란스 병원 진료 예약을 해주세요
# 식사를 하다가 목에 음식이 걸렸어요
# 식사를 하다가 목에 음식이 걸렸어요
# 화재
# 바다에서 조난을 당했어요
# 칼
# 친구가 감전 사고를 당했어요
# 독극물
# 어디선가 연기가 나요 불이 나고 있는 것 같아요
# 아기를 낳을것 같아요
# 우리아이가 갑자기 의식을 잃었어요
# 고압전선
# 어떤 사람이 교통사고를 당했어요
# 말벌에게 쏘였어요
# 말벌에게 쏘였어요
# 의사
# 배가 침몰하고 있어요
# 고압전선
# 고압선이 끊어져 있어요
# 폭우
# 어떤 사람이 건물에서 추락했어요
# 성동구
# 폭탄이 터졌어요
# 아기를 낳을것 같아요
# 아기를 낳을것 같아요
# 강아지가 뼈를 삼켰어요
# 밖에 모르는 사람이 서성거려요
# 낯선남자
# 빨리 와주세요
# 깔리다
# 터널이 무너져 갇혔어요
# 아내가 결박 당해있어요
# 몸이 결박 당해있어요
# 62
# 아파서 못 참을것 같아요
# 독극물
# 아파서 못 참을것 같아요
# 해안가에 상어가 나타났어요
# 해안가에 해파리가 나타났어요
# 몸에 열이 많이 나고 두통이 심해요
# 몸에 열이 많이 나고 두통이 심해요
# 보내주세요구급차
# 어떤 사람이 길거리에서 피를 많이 흘리고 있어요
# 아이가 낳을것 같아요
# 아기가 갑자기 토해요
# 아이를 공원에서 잃어버렸어요
# 아이가 방에 갇혔어요
# 아기를 낳을것 같아요
# 아기를 낳을것 같아요
# 중랑구
# 집이 흔들려요
# 산에서 뱀에게 물렸어요
# 집에 도둑강도이 들어왔어요
# 놀이터
# 아들이 놀이터에서 놀다가 팔이 부러졌어요
# 의사
# 도와주세요 !
# 말벌에게 쏘였어요
# 어떤 사람이 집단폭력을 당하고 있어요
# 은평구
# 지하철 역 안에서 화재가 발생했어요
# 진통제
# 어떤 사람이 무기흉기를 소지하고 있어요
# 산에서 야생동물을 만났어요 저를 공격할 것 같아요
# 무릎 인대를 다친 것 같아요
# 산에서 야생동물을 만났어요 저를 공격할 것 같아요
# 스키를 타다가 넘어져서 못 일어나겠어요
# 기절하다
# 사람이 갑자기 쓰러졌어요
# 창문
# 집이 흔들려요
# 비상약
# 어떤 사람이 길거리에서 피를 많이 흘리고 있어요
# 진통제
# 어떤 사람한테 납치당했어요
# 화상
# 친구가 음식을 먹다가 실수로 방부제를 같이 먹었어요
# 산에서 뱀에게 물렸어요
# 감전 사고가 났어요
# 복통
# 복통이 심해요
# 선반
# 집에 전기가 나갔어요
# 아내가 쓰러졌어요
# 내가 방에 갇혔어요
# 칼
# 친구가 감전 사고를 당했어요
# 가스가 새고 있는 것 같아요
# 무릎 인대를 다친 것 같아요
# 진통제
# 어떤 사람이 칼에 찔려서 피를 많이 흘리고 있어요
# 진통제
# 어떤 사람이 집단폭력을 당하고 있어요
# 산에서 뱀에게 물렸어요
# 감전 사고가 났어요
# 옥상
# 집에 도둑강도이 들어왔어요
# 공사장
# 남편이 높은데서 떨어져서 머리에서 피나요
# 놀이터
# 독버섯을 먹은 것 같아요
# 산에서 야생동물을 만났어요 저를 공격할 것 같아요
# 집에 모르는 사람이 침입했어요
# 아이를 모르는 사람이 데려갔어요
# 아이를 모르는 사람이 데려갔어요
# 집에 도둑강도이 들어왔어요
# 집에 도둑강도이 들어왔어요
# 아이를 공원에서 잃어버렸어요
# 아이가 방에 갇혔어요
# 산에서 야생동물을 만났어요 저를 공격할 것 같아요
# 강도가 들어온것 같아요
# 아내가 쓰러졌어요
# 몸이 결박 당해있어요
# 보내주세요구급차
# 119 구조대를 불러주세요
# 해안가에 상어가 나타났어요
# 여기 서대문구 홍제동 한양아파트인데 옥상에서 사람이 떨어지려고해요
# 화요일
# 112에 신고해주세요
# 결박
# 내가 방에 갇혔어요
# 어디선가 연기가 나요 불이 나고 있는 것 같아요
# 어디선가 연기가 나요 불이 나고 있는 것 같아요
# 운동장
# 아기가 숨을 안 쉬어요
# 발목
# 발목을 접질렀어요
# 45
# 너무 아파요
# 동전
# 비행기가 추락하고 있어요
# 개
# 광견병에 걸린 개에게 물렸어요
# 아이를 공원에서 잃어버렸어요
# 아이가 방에 갇혔어요
# 알려주세요
# 유리가 깨져서 발을 다쳤어요
# 앞집
# 우리 집에 불이 났어요
# 아기를 낳을것 같아요
# 아기를 낳을것 같아요
# 화재
# 화상을 입었어요
# 가스가 새고 있는 것 같아요
# 무릎 인대를 다친 것 같아요
# 의사
# 빨리 도와주세요
# 산에서 야생동물을 만났어요 저를 나고 있는
# 스키를 타다가 넘어져서 못 일어나겠어요
# 어떤 사람이 교통사고를 추락했어요
# 어떤 사람이 교통사고를 당했어요
# 술 취한 사람이 방망이로 사람들을 때리고 있어요
# 술 취한 사람이 방망이로 사람들을 때리고 있어요
# 어떤 사람이 자살을 시도하고 있어요
# 어떤 사람이 바다에 빠졌어요
# 산에서 야생동물을 만났어요 저를 공격할 것 같아요
# 강도가 들어온것 같아요
# 강북구
# 해파리에게 쏘였어요
# 아들이 놀이터에서 놀다가 팔이 부러졌어요
# 아들이 놀이터에서 놀다가 팔이 부러졌어요
# 산에서 뱀에게 물렸어요
# 산에서 뱀에게 물렸어요
# 학생
# 광견병에 걸린 개에게 물렸어요
# 산에서 야생동물을 만났어요 저를 공격할 것 같아요
# 산에서 야생동물을 만났어요 저를 공격할 것 같아요
# 독버섯
# 독버섯을 먹은 것 같아요
# 피나다
# 세브란스 병원 진료 예약을 해주세요
# 아이가 방에 갇혔어요
# 밖에 싸움이 났어요 경찰을 불러주세요
# 술 취한 사람이 방망이로 사람들을 때리고 있어요
# 술 취한 사람이 방망이로 사람들을 때리고 있어요
# 의사
# 도와주세요 !
# 골절
# 엘리베이터가 갑자기 중간에 멈췄어요
# 말벌에게 쏘였어요
# 말벌에게 쏘였어요
# 말벌에게 쏘였어요
# 말벌에게 쏘였어요
# 빨리 와주세요
# 가스가 새고 있는 것 같아요
# 45
# 너무 아파요
# 친구가 음식을 먹다가 실수로 방부제를 같이 먹었어요
# 친구가 음식을 먹다가 실수로 방부제를 같이 먹었어요
# 공원
# 독버섯을 먹은 것 같아요
# 장난감
# 동생이 문틈에 손이 끼었어요
# 운동장
# 아기가 갑자기 토해요
# 강아지가 뼈를 삼켰어요
# 강아지가 뼈를 삼켰어요
# 결박 결박 당해있어요
# 몸이 결박 당해있어요
# 아이가 장난감을 삼켰어요
# 아이가 독극물을 삼켰어요
# 운동장
# 아이가 독극물을 삼켰어요
# 학교
# 문에 몸이 끼었어요
# 성동구
# 폭탄이 터졌어요
# 진통제
# 어떤 사람이 집단폭력을 당하고 있어요
# 밖에 싸움이 났어요 소방차를 불러주세요
# 밖에 싸움이 났어요 경찰을 불러주세요
# 집에 불이 났어요
# 우리 집에 불이 났어요
# 성동구
# 문에 몸이 끼었어요
# 아기를 낳을것 같아요
# 우리아이가 갑자기 의식을 잃었어요
# 말벌에게 쏘였어요
# 어떤 사람이 집단폭력을 당하고 있어요
# 어떤 사람이 저를 죽이려고 해요
# 어떤 사람이 저를 죽이려고 해요
# 공사장
# 사람이 무거운 물건에 깔렸어요
# 화요일
# 어떤 사람이 칼로 위협하고 있어요
# 보내주세요구급차
# 어디선가 연기가 나요 불이 나고 있는 것 같아요
# 보내주세요구급차
# 엄마가 신장병에 있는데 쓰러지셨어요
# 해안가에 상어가 나타났어요
# 여기 서대문구 홍제동 한양아파트인데 옥상에서 사람이 떨어지려고해요
# 화재
# 친구가 음식을 먹다가 실수로 방부제를 같이 먹었어요
# 아이를 공원에서 잃어버렸어요
# 아이를 공원에서 잃어버렸어요
# 진통제
# 동생이 문틈에 손이 끼었어요
# 신체부위가 절단됐어요
# 신체부위가 절단됐어요
# 아이가 장난감을 삼켰어요
# 아이가 독극물을 삼켰어요
# 허리가 아파서 일어날 수 없어요
# 여기 서대문구 홍제동 한양아파트인데 옥상에서 사람이 떨어지려고해요
# 근처에서 폭탄이 터졌어요
# 근처에서 폭탄이 터졌어요
# 진통제
# 어떤 사람한테 납치당했어요
# 아들이 놀이터에서 놀다가 팔이 부러졌어요
# 아들이 놀이터에서 놀다가 팔이 부러졌어요
#

# 어떤 사람이 교통사고를 당했어요
# 어떤 사람이 건물에서 추락했어요
# 걸렸다
# 112에 신고해주세요
# 유리가 깨져서 발을 다쳤어요
# 유리가 깨져서 발을 다쳤어요
# 교통사고
# 문에 몸이 끼었어요
# 보내주세요구급차
# 119 구조대를 불러주세요
# 밖에 불이 났어요 소방차를 불러주세요
# 밖에 불이 났어요 소방차를 불러주세요
# 배
# 동생이 문틈에 손이 끼었어요
# 알려주세요
# 윗집에 불이 났어요
# 어떤 사람이 벼락을 맞았어요
# 어떤 사람이 벼락을 맞았어요
# 산에서 뱀에게 물렸어요
# 감전 사고가 났어요
# 경찰
# 쫓아오는 것 같아요
# 복통
# 너무 아파요
# 알려주세요
# 옆집에 불이 났어요
# 장단지
# 발목을 접질렀어요
# 보내주세요구급차
# 급류에 친구가 휩쓸렸어요
# 보내주세요구급차
# 엄마가 신장병에 있는데 쓰러지셨어요
# 말벌에게 쏘였어요
# 말벌에게 쏘였어요
# 보내주세요구급차
# 이상한 사람이 저를 쫓아와요
# 집에 모르는 사람이 데려갔어요
# 홍수가 나서 집이 물에 잠기고 있어요
# 트럭
# 감전 사고가 났어요
# 진통제
# 어떤 사람한테 납치당했어요
# 진통제
# 어떤 사람이 무기흉기를 소지하고 있어요
# 파편
# 가스가 새고 있어요
# 어디선가 연기가 나요 음식이 걸렸어요
# 어디선가 연기가 나요 불이 나고 있는 것 같아요
# 강서구
# 내가 방에 갇혔어요
# 의사
# 아내가 쓰러졌어요
# 알려주세요
# 집에 모르는 사람이 침입했어요
# 학생
# 신체부위가 절단됐어요
# 누전
# 집에 전기가 나갔어요
# 산에서 뱀에게 물렸어요
# 산에서 뱀에게 물렸어요
# 허리가 아파서 일어날 수 없어요
# 허리가 아파서 일어날 수 없어요
# 어떤 사람이 자살을 시도하고 있어요
# 어떤 사람이 자살을 시도하고 있어요
# 아이를 공원에서 잃어버렸어요
# 아이를 공원에서 잃어버렸어요
# 옆집 흔들려요
# 윗집에 불이 났어요
# 허리가 아파서 일어날 수 없어요
# 쫓아오는 것 같아요
# 기절하다
# 광견병에 걸린 개에게 물렸어요
# 진통제
# 산에서 뱀에게 물렸어요
# 의사
# 도와주세요 !
# 엘리베이터가 갑자기 중간에 멈췄어요
# 엘리베이터가 갑자기 중간에 멈췄어요
# 말벌에게 쏘였어요
# 말벌에게 쏘였어요
# 산에서 뱀에게 물렸어요
# 집에 불이 났어요
# 보내주세요구급차
# 해파리에게 쏘였어요
# 허리가 아파서 일어날 수 없어요
# 허리가 아파서 일어날 수 없어요
# 운동장
# 아기가 갑자기 토해요
# 집에 도둑강도이 들어왔어요
# 아랫집에 불이 났어요
# 낫
# 어떤 사람이 무기흉기를 소지하고 있어요
# 산에서 야생동물을 만났어요 저를 공격할 것 같아요
# 산에서 야생동물을 만났어요 저를 공격할 것 같아요
# 근처에서 폭탄이 터졌어요
# 근처에서 폭탄이 터졌어요
# 거실
# 아이를 공원에서 잃어버렸어요
# 성동구
# 고압선이 끊어져 있어요
# 어디선가 연기가 나요 불이 나고 있는 있는 있는 있는 있는 s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s
# 어디선가 연기가 나요 불이 나고 있는 것 같아요
# 낯선남자
# 비행기가 추락하고 있어요
# 멧돼지
# 어떤 사람이 바다에 빠졌어요
# 말벌에게 쏘였어요
# 어지러워서 서있을 수 없어요
# 해안가에 상어가 나타났어요
# 해안가에 해파리가 나타났어요
# 화요일
# 숨이 안 쉬어져요
# 칼
# 가스가 새고 있어요
# 경찰
# 어지러워서 서있을 수 없어요
# 진통제
# 허리가 아파서 일어날 수 없어요
# 가스가 새고 있는 것 같아요
# 가스가 새고 있는 것 같아요
# 어떤 사람이 무기흉기를 소지하고 있어요
# 어떤 사람이 벼락을 맞았어요
# 연기
# 어디선가 연기가 나요 불이 나고 있는 것 같아요
# 해안가에 상어가 나타났어요
# 쫓아오는 것 같아요
# 말벌에게 쏘였어요
# 해안가에 해파리가 나타났어요
# 해안가에 상어가 나타났어요
# 해안가에 상어가 나타났어요
# 목
# 너무 아파요
# 성동구
# 폭탄이 터졌어요
# 창문
# 배가 침몰하고 있어요
# 약국
# 친구가 감전 사고를 당했어요
# 아이가 낳을것 같아요
# 아기가 갑자기 토해요
# 질식
# 어떤 사람이 교통사고를 당했어요
# 산에서 뱀에게 물렸어요
# 감전 사고가 났어요
# 고압전선
# 근처에서 폭탄이 터졌어요
# 깔리다
# 터널이 무너져 갇혔어요
# 은평구
# 지하철 역 안에서 화재가 발생했어요
# 보내주세요구급차
# 119 구조대를 불러주세요
# 성동구
# 고압선이 끊어져 있어요
# 해안가에 상어가 나타났어요
# 해안가에 해파리가 나타났어요
# 경찰
# 어떤 사람이 길거리에서 피를 많이 흘리고 있어요
# 진통제
# 어떤 사람이 칼에 찔려서 피를 많이 흘리고 있어요
# 걸렸다
# 식사를 하다가 목에 음식이 걸렸어요
# 몸에 열이 많이 나고 두통이 심해요
# 몸에 열이 많이 나고 두통이 심해요
# 아이가 갑자기 의식을 잃었어요
# 아기가 갑자기 토해요
# 산에서 야생동물을 만났어요 저를 공격할 것 같아요
# 강도가 들어온것 같아요
# 아이를 공원에서 잃어버렸어요
# 내가 방에 갇혔어요
# 의사
# 빨리 도와주세요
# 아이가 장난감을 삼켰어요
# 아이가 독극물을 삼켰어요
# 집에 불이 났어요
# 아랫집에 불이 났어요
# 아이가 장난감을 삼켰어요
# 아기가 장난감을 사켰어요
# 아이가 말벌에 쏘여서 기절했어요
# 아이가 말벌에 쏘여서 기절했어요
# 산에서 뱀에게 물렸어요
# 산에서 뱀에게 물렸어요
# 끓는물
# 고속도로에서 자동차가 갑자기 멈췄어요
# 산에서 뱀에게 물렸어요
# 아랫집에 불이 났어요
# 운동장
# 아기가 갑자기 토해요
# 산에서 야생동물을 만났어요 다쳤어요
# 밖에 불이 났어요 소방차를 불러주세요
# 화요일
# 숨이 안 쉬어져요
# 식사를 하다가 목에 음식이 걸렸어요
# 식사를 하다가 목에 음식이 걸렸어요
# 산에서 뱀에게 물렸어요
# 집에 불이 났어요
# 보내주세요구급차
# 119 구조대를 불러주세요
# 밖에 싸움이 났어요 소방차를 불러주세요
# 밖에 불이 났어요 소방차를 불러주세요
# 어떤 사람이 자살을 시도하고 있어요
# 어떤 사람이 자살을 시도하고 있어요
# 보내주세요구급차
# 해파리에게 쏘였어요
# 아들이 놀이터에서 놀다가 팔이 부러졌어요
# 아들이 놀이터에서 놀다가 팔이 부러졌어요
# 근처에 있는 건물이 붕괴되고 있어요
# 근처에 있는 건물이 붕괴되고 있어요
# 해안가에 상어가 나타났어요
# 해안가에 상어가 나타났어요
# 경찰차
# 할머니가 갑자기 쓰러지셨어요
# 공원
# 밖에 모르는 사람이 서성거려요
# 선반
# 집에 전기가 나갔어요
# 아이가 방에 갇혔어요
# 사람이 무거운 물건에 깔렸어요
# 도와주세요
# 도와주세요 !
# 산에서 야생동물을 만났어요 저를 공격할 것 같아요
# 산에서 야생동물을 만났어요 저를 공격할 것 같아요
# 탈골
# 고속도로에서 자동차가 갑자기 멈췄어요
# 연기
# 어디선가 연기가 나요 불이 나고 있는 것 같아요
# 진통제
# 어떤 사람이 칼에 찔려서 피를 많이 흘리고 있어요
# 아들이 놀이터에서 놀다가 팔이 부러졌어요
# 아들이 놀이터에서 놀다가 팔이 부러졌어요
# 밖에 싸움이 났어요 경찰을 불러주세요
# 밖에 싸움이 났어요 경찰을 불러주세요
# 알려주세요
# 유리가 깨져서 발을 다쳤어요
# 학생
# 어떤 사람이 벼락을 맞았어요
# 알려주세요
# 집에 모르는 사람이 침입했어요
# 해안가에 상어가 나타났어요
# 해안가에 상어가 나타났어요
# 운동장
# 아이가 독극물을 삼켰어요
# 진통제
# 어떤 사람이 무기흉기를 소지하고 있어요
# 코
# 숨이 안 쉬어져요
# 경찰
# 어지러워서 서있을 수 없어요
# 선반
# 어떤 사람이 건물에서 추락했어요
# 어떤 사람이 저를 죽이려고 해요
# 어떤 사람이 벼락을 맞았어요
# 아이가 장난감을 삼켰어요
# 아이가 독극물을 삼켰어요
# 반점생기다
# 음식을 하다가 손가락을 칼에 베였어요
# 열
# 차 안에 강아지가 방치되어있어요
# 밖에 모르는 사람이 서성거려요
# 밖에 모르는 사람이 서성거려요
# 아기를 낳을것 같아요
# 여기 서대문구 홍제동 한양아파트인데 옥상에서 사람이 떨어지려고해요
# 공사장
# 스키를 타다가 넘어져서 못 일어나겠어요
# 강풍
# 어떤 사람이 집단폭력을 당하고 있어요
# 의사
# 친구가 숨을 안 쉬는 것 같아요
# 산에서 야생동물을 만났어요 저를 공격할 것 같아요
# 강도가 들어온것 같아요
# 산에서 불이 났어요
# 친구가 감전 사고를 당했어요
# 집에 도둑강도이 들어왔어요
# 집에 모르는 사람이 침입했어요
# 식사를 하다가 목에 음식이 걸렸어요
# 식사를 하다가 목에 음식이 걸렸어요
# 진통제
# 어떤 사람이 바다에 빠졌어요
# 학생
# 어떤 사람이 교통사고를 당했어요
# 이물질
# 남편이 높은데서 떨어져서 머리에서 피나요
# 보내주세요구급차
# 112에 신고해주세요
# 바다에서 조난을 당했어요
# 바다에서 조난을 당했어요
# 배
# 복통이 심해요
# 보내주세요구급차
# 할머니가 갑자기 쓰러지셨어요
# 열
# 밖에 불이 났어요 소방차를 불러주세요
# 보내주세요구급차
# 해안가에 해파리가 나타났어요
# 허리가 와주세요
# 강아지가 뼈를 삼켰어요
# 화요일
# 숨이 안 쉬어져요
# 아기를 낳을것 같아요
# 집 벽이 무너질려고 해요
# 강서구
# 차 안에 강아지가 방치되어있어요
# 학생
# 신체부위가 절단됐어요
# 독버섯
# 독버섯을 먹은 것 같아요
# 아이를 공원에서 잃어버렸어요
# 아이를 공원에서 잃어버렸어요
# 가시
# 비행기가 추락하고 있어요
# 운동장
# 아기가 숨을 안 쉬어요
# 산에서 야생동물을 만났어요 저를 공격할 심해요
# 주변 구조물이 무너져서 몸이 끼었어요 몸을 움직이지 못하겠어요
# 끓는물
# 음식을 하다가 손가락을 칼에 베였어요
# 복통
# 너무 아파요
# 어떤 사람이 자살을 시도하고 있어요
# 어떤 사람이 바다에 빠졌어요
# 엘리베이터
# 밖에 싸움이 났어요 경찰을 불러주세요
# 보내주세요구급차
# 할머니가 갑자기 쓰러지셨어요
# 아파트
# 가스가 새고 있어요
# 아이를 공원에서 잃어버렸어요
# 엘리베이터가 갑자기 중간에 멈췄어요
# 물
# 눈에 이물질이 들어갔어요
# 보내주세요구급차
# 급류에 친구가 휩쓸렸어요
# 트럭
# 도와주세요 !
# 놀이터
# 내가 방에 갇혔어요
# 끓는물
# 바다에서 조난을 당했어요
# 빨리 와주세요
# 빨리 와주세요
# 산에서 뱀에게 물렸어요
# 근처에 있는 건물이 붕괴되고 있어요
# 열
# 차 안에 강아지가 방치되어있어요
# 의사
# 도와주세요 !
# 폭우
# 홍수가 나서 집이 물에 잠기고 있어요
# 의사
# 산에서 뱀에게 물렸어요
# 진통제
# 동생이 문틈에 손이 끼었어요
# 질식
# 어떤 사람이 건물에서 추락했어요
# 진통제
# 감전 사고가 났어요
# 산에서 뱀에게 물렸어요
# 옆집에 불이 났어요
# 의사
# 아이가 방에 갇혔어요
# 말벌에게 쏘였어요
# 이상한 사람이 저를 쫓아와요
# 공사장
# 터널이 무너져 갇혔어요
# 아이를 모르는 사람이 데려갔어요
# 홍수가 나서 집이 물에 잠기고 있어요
# 성동구
# 폭탄이 터졌어요
# 복통
# 복통이 심해요
# 탈골
# 엘리베이터가 갑자기 중간에 멈췄어요
# 허리가 와주세요
# 밖에 모르는 사람이 서성거려요
# 밖에 불이 났어요 소방차를 불러주세요
# 밖에 불이 났어요 소방차를 불러주세요
# 신체부위가 절단됐어요
# 신체부위가 절단됐어요
# 유리가 깨져서 발을 다쳤어요
# 주변 구조물이 무너져서 몸이 끼었어요 몸을 움직이지 못하겠어요
# 아들
# 너무 아파요
# 집에 불이 났어요
# 우리 집에 불이 났어요
# 집에 도둑강도이 들어왔어요
# 집에 도둑강도이 들어왔어요
# 어떤 사람이 자살을 시도하고 있어요
# 어떤 사람이 칼에 찔려서 피를 많이 흘리고 있어요
# 산에서 야생동물을 만났어요 쉬는 것 같아요
# 화상을 입었어요
# 고압전선
# 폭탄이 터졌어요
# 급류에 하다가 손가락을 칼에 베였어요
# 급류에 친구가 휩쓸렸어요
# 강북구
# 급류에 친구가 휩쓸렸어요
# 놀이터
# 밖에 모르는 사람이 서성거려요
# 유리가 깨져서 발을 다쳤어요
# 주변 구조물이 무너져서 몸이 끼었어요 몸을 움직이지 못하겠어요
# 차
# 차 안에 강아지가 방치되어있어요
# 체온계
# 몸에 열이 많이 나고 두통이 심해요
# 걸렸다
# 급류에 친구가 휩쓸렸어요
# 기절하다
# 사람이 갑자기 쓰러졌어요
# 강북구
# 급류에 친구가 휩쓸렸어요
# 아내가 쓰러졌어요
# 아내가 쓰러졌어요
# 고압전선
# 집에 전기가 나갔어요
# 비상약
# 가스가 새고 있는 것 같아요
# 누수
# 빨리 와주세요
# 말벌에게 쏘였어요
# 어지러워서 서있을 수 없어요
# 유리가 깨져서 발을 다쳤어요
# 유리가 깨져서 발을 다쳤어요
# 화요일
# 어떤 사람이 칼로 위협하고 있어요
# 보내주세요구급차
# 세브란스 병원 진료 예약을 해주세요
# 연기
# 어디선가 연기가 나요 불이 나고 있는 것 같아요
# 아이가 장난감을 삼켰어요
# 아기가 장난감을 사켰어요
# 유리가 깨져서 발을 다쳤어요
# 유리가 깨져서 발을 다쳤어요
# 산에서 뱀에게 물렸어요
# 산에서 뱀에게 물렸어요
# 화요일
# 해안가에 상어가 나타났어요
# 터널이 방에 갇혔어요
# 몸에 열이 많이 나고 두통이 심해요
# 소화기
# 친구가 음식을 먹다가 실수로 방부제를 같이 먹었어요
# 집에 흔들려요
# 아랫집에 불이 났어요
# 고압전선
# 어떤 사람이 교통사고를 당했어요
# 95
# 어떤 사람이 길거리에서 피를 많이 흘리고 있어요
# 산에서 뱀에게 물렸어요
# 스키를 타다가 넘어져서 못 일어나겠어요
# 산에서 야생동물을 만났어요 저를 공격할 것 같아요
# 산에서 야생동물을 만났어요 저를 공격할 것 같아요
# 아이를 공원에서 잃어버렸어요
# 아이를 공원에서 잃어버렸어요
# 아파트
# 문에 몸이 끼었어요
# 약국
# 친구가 감전 사고를 당했어요
# 알려주세요
# 배가 침몰하고 있어요
# 알려주세요
# 사람이 무거운 물건에 깔렸어요
# 산에서 뱀에게 물렸어요
# 사람이 무거운 물건에 깔렸어요
# 집에 불이 났어요
# 집에 불이 났어요
# 산에서 야생동물을 당해있어요
# 아내가 쓰러졌어요
# 화재
# 친구가 음식을 먹다가 실수로 방부제를 같이 먹었어요
# 독극물
# 어떤 사람이 칼로 위협하고 있어요
# 탈골
# 엘리베이터가 갑자기 중간에 멈췄어요
# 엘리베이터
# 밖에 싸움이 났어요 경찰을 불러주세요
# 산에서 야생동물을 만났어요 저를 공격할 심해요
# 주변 구조물이 무너져서 몸이 끼었어요 몸을 움직이지 못하겠어요
# 학생
# 우리아이가 갑자기 의식을 잃었어요
# 보내주세요구급차
# 이상한 사람이 저를 쫓아와요
# 45
# 근처에서 폭탄이 터졌어요
# 어떤 사람이 무기흉기를 소지하고 있어요
# 어떤 사람이 저를 죽이려고 해요
# 엘리베이터
# 내가 방에 갇혔어요
# 말벌에게 쏘였어요
# 어떤 사람한테 납치당했어요
# 공사장
# 남편이 높은데서 떨어져서 머리에서 피나요
# 근처에 있는 건물이 붕괴되고 있어요
# 근처에 있는 건물이 붕괴되고 있어요
# 말벌에게 쏘였어요
# 어지러워서 서있을 수 없어요
# 의사
# 내가 방에 갇혔어요
# 옆집 흔들려요
# 옆집에 불이 났어요
# 학생
# 신체부위가 절단됐어요
# 알려주세요
# 가스가 새고 있어요
# 유리가 깨져서 발을 다쳤어요
# 남편이 높은데서 떨어져서 머리에서 피나요
# 집에 도둑강도이 들어왔어요
# 집에 모르는 사람이 침입했어요
# 유리가 깨져서 발을 다쳤어요
# 유리가 깨져서 발을 다쳤어요
# 학생
# 아기를 낳을것 같아요
# 어떤 사람이 바다에 빠졌어요
# 어떤 사람이 바다에 빠졌어요
# 진통제
# 어떤 사람이 칼에 찔려서 피를 많이 흘리고 있어요
# 옆집 흔들려요
# 집이 흔들려요
# 운동장
# 아기를 낳을것 같아요
# 옥상
# 집에 도둑강도이 들어왔어요
# 아이가 장난감을 삼켰어요
# 아이가 장난감을 삼켰어요
# 집에 불이 났어요
# 친구가 감전 사고를 당했어요
# 낫
# 빨리 와주세요
# 걸렸다
# 숨이 안 쉬어져요
# 산에서 뱀에게 물렸어요
# 우리 집에 불이 났어요
# 100
# 허리가 아파서 일어날 수 없어요
# 어떤 사람이 자살을 시도하고 있어요
# 어떤 사람이 바다에 빠졌어요
# 술 취한 사람이 방망이로 사람들을 때리고 있어요
# 술 취한 사람이 방망이로 사람들을 때리고 있어요
# 성동구
# 집에 전기가 나갔어요
# 아이가 장난감을 삼켰어요
# 아기가 장난감을 사켰어요
# 산에서 뱀에게 물렸어요
# 빨리 도와주세요
# 산에서 장난감을 삼켰어요
# 해안가에 상어가 나타났어요
# 운동장
# 아기가 갑자기 토해요
# 연기
# 눈에 이물질이 들어갔어요
# 터널이 방에 갇혔어요
# 터널이 무너져 갇혔어요
# 보내주세요구급차
# 119 구조대를 불러주세요
# 어디선가 하다가 손가락을 칼에 베였어요
# 바다에서 조난을 당했어요
# 왼쪽-눈
# 문에 몸이 끼었어요
# 아내가 결박 당해있어요
# 몸이 결박 당해있어요
# 아이가 장난감을 삼켰어요
# 아이가 독극물을 삼켰어요
# 45
# 비행기가 추락하고 있어요
# 산에서 뱀에게 물렸어요
# 친구가 숨을 안 쉬는 것 같아요
# 아이가 장난감을 삼켰어요
# 아기가 장난감을 사켰어요
# 의사
# 배가 침몰하고 있어요
# 아이가 숨을 안 쉬어요
# 아기가 숨을 안 쉬어요
# 화요일
# 아파서 못 참을것 같아요
# 산에서 야생동물을 만났어요 저를 공격할 것 같아요
# 스키를 타다가 넘어져서 못 일어나겠어요
# 진통제
# 어떤 사람이 집단폭력을 당하고 있어요
# 아이가 말벌에 쏘여서 기절했어요
# 아이가 말벌에 쏘여서 기절했어요
# 강북구
# 해파리에게 쏘였어요
# 깔리다
# 터널이 무너져 갇혔어요
# 진통제
# 광견병에 걸린 개에게 물렸어요
# 아이가 장난감을 삼켰어요
# 아기가 숨을 안 쉬어요
# 집에 불이 났어요
# 아랫집에 불이 났어요
# 산에서 뱀에게 물렸어요
# 주변 구조물이 무너져서 몸이 끼었어요 몸을 움직이지 못하겠어요
# 중랑구
# 옆집에 불이 났어요
# 해안가에 상어가 나타났어요
# 해안가에 해파리가 나타났어요
# 벼락
# 가스가 새고 있는 것 같아요
# 경찰차
# 광견병에 걸린 개에게 물렸어요
# 말벌에게 쏘였어요
# 말벌에게 쏘였어요
# 산에서 야생동물을 만났어요 저를 공격할 심해요
# 스키를 타다가 넘어져서 못 일어나겠어요
# 공사장
# 남편이 높은데서 떨어져서 머리에서 피나요
# 벼락
# 가스가 새고 있어요
# 45
# 어떤 사람이 칼로 위협하고 있어요
# 아이를 모르는 사람이 칼에 베였어요
# 바다에서 조난을 당했어요
# 빨리 와주세요
# 빨리 와주세요
# 보내주세요구급차
# 119 구조대를 불러주세요
# 보내주세요구급차
# 세브란스 병원 진료 예약을 해주세요
# 의사
# 몸이 결박 당해있어요
# 피나다
# 음식을 하다가 손가락을 칼에 베였어요
# 아이가 장난감을 삼켰어요
# 아이가 장난감을 삼켰어요
# 식사를 하다가 목에 음식이 걸렸어요
# 식사를 하다가 목에 음식이 걸렸어요
# 강북구
# 해파리에게 쏘였어요
# 은평구
# 지하철 역 안에서 화재가 발생했어요
# 산에서 야생동물을 만났어요 저를 공격할 것 같아요
# 독버섯을 먹은 것 같아요
# 창문
# 집이 흔들려요
# 화요일
# 복통이 심해요
# 어떤 사람이 교통사고를 당했어요
# 어떤 사람이 건물에서 추락했어요
# 알려주세요
# 집에 모르는 사람이 침입했어요
# 중랑구
# 배가 침몰하고 있어요
# 의사
# 친구가 숨을 안 쉬는 것 같아요
# 아기를 낳을것 같아요
# 우리아이가 갑자기 의식을 잃었어요
# 끓는물
# 바다에서 조난을 당했어요
# 가스가 새고 있는 것 같아요
# 가스가 새고 있어요
# 아들
# 복통이 심해요
# 산에서 야생동물을 만났어요 저를 공격할 것 같아요
# 강도가 들어온것 같아요
# 집에 도둑강도이 들어왔어요
# 아랫집에 불이 났어요
# 아이를 모르는 사람이 데려갔어요
# 아이를 모르는 사람이 데려갔어요
# 산에서 야생동물을 만났어요 저를 공격할 심해요
# 여기 서대문구 홍제동 한양아파트인데 옥상에서 사람이 떨어지려고해요
# 깔리다
# 발목을 접질렀어요
# 산에서 뱀에게 물렸어요
# 사람이 무거운 물건에 깔렸어요
# 산에서 야생동물을 만났어요 저를 공격할 것 같아요
# 강도가 들어온것 같아요
# 화상
# 우리 집에 불이 났어요
# 집에 전기가 나갔어요
# 집에 전기가 나갔어요
# 허리가 아파서 일어날 수 없어요
# 어떤 사람이 길거리에서 피를 많이 흘리고 있어요
# 화재
# 우리 집에 불이 났어요
# 산에서 뱀에게 났어요
# 화상을 입었어요
# 아이를 공원에서 잃어버렸어요
# 아이를 공원에서 잃어버렸어요
# 보내주세요구급차
# 해파리에게 쏘였어요
# 몸에 열이 많이 나고 두통이 심해요
# 몸에 열이 많이 나고 두통이 심해요
# 의사
# 내가 방에 갇혔어요
# 어디선가 연기가 나요 불이 나고 있는 것 같아요
# 여기 서대문구 홍제동 한양아파트인데 옥상에서 사람이 떨어지려고해요
# 집에 불이 났어요
# 집에 불이 났어요
# 탈골
# 고속도로에서 자동차가 갑자기 멈췄어요
# 45
# 어떤 사람이 칼로 위협하고 있어요
# 강풍
# 어떤 사람한테 납치당했어요
# 아내가 쓰러졌어요
# 몸이 결박 당해있어요
# 공원
# 산에서 야생동물을 만났어요 저를 공격할 것 같아요
# 공원
# 강아지가 뼈를 삼켰어요
# 어떤 사람이 칼에 찔려서 피를 많이 흘리고 있어요
# 어떤 사람이 바다에 빠졌어요
# 소화기
# 밖에 싸움이 났어요 경찰을 불러주세요
# 의사
# 지하철 역 안에서 화재가 발생했어요
# 알려주세요
# 집에 모르는 사람이 침입했어요
# 보내주세요구급차
# 이상한 사람이 저를 쫓아와요
# 집에 도둑강도이 들어왔어요
# 집에 도둑강도이 들어왔어요
# 터널이 있는 건물이 붕괴되고 있어요
# 터널이 무너져 갇혔어요
# 술 취한 사람이 방망이로 사람들을 때리고 있어요
# 술 취한 사람이 방망이로 사람들을 때리고 있어요
# 운동장
# 아기가 갑자기 토해요
# 고압전선
# 고압선이 끊어져 있어요
# 앞집
# 집이 흔들려요
# 아이를 모르는 사람이 데려갔어요
# 아이를 모르는 사람이 데려갔어요
# 옆집
# 주변 구조물이 무너져서 몸이 끼었어요 몸을 움직이지 못하겠어요
# 강북구
# 급류에 친구가 휩쓸렸어요
# 강북구
# 해파리에게 쏘였어요
# 말벌에게 쏘였어요
# 허리가 아파서 일어날 수 없어요
# 몸에 열이 많이 나고 두통이 심해요
# 몸에 열이 많이 나고 두통이 심해요
# 산에서 야생동물을 만났어요 저를 공격할 심해요
# 강도가 들어온것 같아요
# 의사
# 빨리 도와주세요
# 아이가 장난감을 삼켰어요
# 아기가 장난감을 사켰어요
# 아이가 말벌에 쏘여서 기절했어요
# 아이가 말벌에 쏘여서 기절했어요
# 화요일
# 허리가 아파서 일어날 수 없어요
# 성동구
# 고압선이 끊어져 있어요
# 트럭
# 산에서 뱀에게 물렸어요
# 아이가 장난감을 삼켰어요
# 아이가 장난감을 삼켰어요
# 어떤 사람이 무기흉기를 소지하고 있어요
# 어떤 사람이 칼로 위협하고 있어요
# 몸에 열이 많이 나고 두통이 심해요
# 남편이 높은데서 떨어져서 머리에서 피나요
# 강아지가 뼈를 삼켰어요
# 강아지가 뼈를 삼켰어요
# 진통제
# 쫓아오는 것 같아요
# 의사
# 감전 사고가 났어요
# 발목
# 발목을 접질렀어요
# 아기를 낳을것 같아요
# 우리아이가 갑자기 의식을 잃었어요
# 폭우
# 근처에서 폭탄이 터졌어요
# 어떤 사람이 건물에서 추락했어요
# 어떤 사람이 건물에서 추락했어요
# 성북구
# 아랫집에 불이 났어요
# 진통제
# 어떤 사람이 자살을 시도하고 있어요
# 연기
# 쫓아오는 것 같아요
# 우리아이가 갑자기 의식을 잃었어요
# 우리아이가 갑자기 의식을 잃었어요
# 연기
# 신체부위가 절단됐어요
# 성동구
# 폭탄이 터졌어요
# 비상약
# 강아지가 뼈를 삼켰어요
# 아이가 말벌에 쏘여서 기절했어요
# 아이가 말벌에 쏘여서 기절했어요
# 산에서 야생동물을 만났어요 저를 공격할 것 같아요
# 주변 구조물이 무너져서 몸이 끼었어요 몸을 움직이지 못하겠어요
# 산에서 야생동물을 만났어요 다쳤어요
# 유리가 깨져서 발을 다쳤어요
# 말벌에게 쏘였어요
# 어떤 사람이 무기흉기를 소지하고 있어요
# 산에서 뱀에게 물렸어요
# 옆집에 불이 났어요
# 소화기
# 아내가 쓰러졌어요
# 진통제
# 어떤 사람한테 납치당했어요
# 앞집
# 집이 흔들려요
# 성동구
# 집에 전기가 나갔어요
# 몸에 열이 많이 나고 두통이 심해요
# 친구가 음식을 먹다가 실수로 방부제를 같이 먹었어요
# 진통제
# 어떤 사람이 자살을 시도하고 있어요
# 복통
# 복통이 심해요
# 해안가에 상어가 나타났어요
# 숨이 안 쉬어져요
# 밖에 모르는 사람이 서성거려요
# 112에 신고해주세요
# 약국
# 독버섯을 먹은 것 같아요
# 화요일
# 아파서 못 참을것 같아요
# 아파트
# 무릎 인대를 다친 것 같아요
# 집에 도둑강도이 들어왔어요
# 윗집에 불이 났어요
# 아이를 공원에서 잃어버렸어요
# 아이를 공원에서 잃어버렸어요
# 보내주세요구급차
# 119 구조대를 불러주세요
# 강풍
# 허리가 아파서 일어날 수 없어요
# 학생
# 신체부위가 절단됐어요
# 아이가 낳을것 같아요
# 아기가 갑자기 토해요
# 아기를 낳을것 같아요
# 아기를 낳을것 같아요
# 아기를 낳을것 같아요
# 집 벽이 무너질려고 해요
# 음식물
# 어디선가 연기가 나요 불이 나고 있는 것 같아요
# 어떤 사람이 자살을 시도하고 있어요
# 어떤 사람이 칼에 찔려서 피를 많이 흘리고 있어요
# 발목을 접질렀어요
# 발목을 접질렀어요
# 소화기
# 고속도로에서 자동차가 갑자기 멈췄어요
# 어떤 사람이 무기흉기를 소지하고 있어요
# 어떤 사람이 저를 죽이려고 해요
# 어떤 사람이 무기흉기를 소지하고 있어요
# 어떤 사람이 벼락을 맞았어요
# 어떤 사람이 교통사고를 당했어요
# 어떤 사람이 교통사고를 당했어요
# 해안가에 상어가 나타났어요
# 해안가에 해파리가 나타났어요
# 알려주세요
# 사람이 무거운 물건에 깔렸어요
# 독버섯
# 독버섯을 먹은 것 같아요
# 집에 불이 났어요
# 집에 불이 났어요
# 독극물
# 숨이 안 쉬어져요
# 걸렸다
# 112에 신고해주세요
# 성북구
# 동생이 문틈에 손이 끼었어요
# 아이가 장난감을 삼켰어요
# 아이가 장난감을 삼켰어요
# 근처에서 폭탄이 터졌어요
# 근처에서 폭탄이 터졌어요
# 아파트
# 가스가 새고 있어요
# 독버섯
# 독버섯을 먹은 것 같아요
# 술 취한 사람이 방망이로 사람들을 때리고 있어요
# 술 취한 사람이 방망이로 사람들을 때리고 있어요
# 학생
# 어떤 사람이 벼락을 맞았어요
# 기절하다
# 사람이 갑자기 쓰러졌어요
# 소화기
# 친구가 음식을 먹다가 실수로 방부제를 같이 먹었어요
# 파편
# 가스가 새고 있는 것 같아요
# 아기를 낳을것 같아요
# 집 벽이 무너질려고 해요
# 열
# 차 안에 강아지가 방치되어있어요
# 보내주세요구급차
# 119 구조대를 불러주세요
# 월요일
# 어떤 사람이 칼로 위협하고 있어요
# 결박 결박 당해있어요
# 몸이 결박 당해있어요
# 아이를 모르는 사람이 데려갔어요
# 아이를 모르는 사람이 데려갔어요
# 허리가 와주세요
# 강아지가 뼈를 삼켰어요
# 말벌에게 쏘였어요
# 어떤 사람한테 납치당했어요
# 공사장
# 남편이 높은데서 떨어져서 머리에서 피나요
# 성북구
# 집이 흔들려요
# 강북구
# 화상을 입었어요
# 배
# 복통이 심해요
# 소화기
# 고속도로에서 자동차가 갑자기 멈췄어요
# 코
# 눈에 이물질이 들어갔어요
# 터널이 무너져 갇혔어요
# 터널이 무너져 갇혔어요
# 아이를 모르는 사람이 데려갔어요
# 홍수가 나서 집이 물에 잠기고 있어요
# 집에 도둑강도이 들어왔어요
# 집에 모르는 사람이 침입했어요
# 고압전선
# 고압선이 끊어져 있어요
# 어떤 사람이 무기흉기를 소지하고 있어요
# 어떤 사람이 무기흉기를 소지하고 있어요
# 산에서 뱀에게 물렸어요
# 산에서 뱀에게 물렸어요
# 보내주세요구급차
# 엄마가 신장병에 있는데 쓰러지셨어요
# 발작
# 광견병에 걸린 개에게 물렸어요
# 말벌에게 쏘였어요
# 사람이 갑자기 쓰러졌어요
# 말벌에게 쏘였어요
# 엄마가 신장병에 있는데 쓰러지셨어요
# 산에서 뱀에게 s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s
# 지하철 역 안에서 화재가 발생했어요
# 산에서 뱀에게 물렸어요
# 옆집에 불이 났어요
# 기절하다
# 사람이 갑자기 쓰러졌어요
# 진통제
# 어떤 사람한테 납치당했어요
# 바다에서 조난을 당했어요
# 바다에서 조난을 당했어요
# 아이를 모르는 사람이 데려갔어요
# 아이를 모르는 사람이 데려갔어요
# 몸에 열이 많이 나고 두통이 심해요
# 몸에 열이 많이 나고 두통이 심해요
# 끓는물
# 음식을 하다가 손가락을 칼에 베였어요
# 아내가 쓰러졌어요
# 아내가 쓰러졌어요
# 고압전선
# 폭탄이 터졌어요
# 화요일
# 눈에 이물질이 들어갔어요
# 말벌에게 쏘였어요
# 해안가에 해파리가 나타났어요
# 보내주세요구급차
# 비행기가 추락하고 있어요
# 어디선가 연기가 나요 불이 나고 같이 같이 먹었어요
# 친구가 음식을 먹다가 실수로 방부제를 같이 먹었어요
# 아이가 장난감을 삼켰어요
# 아이가 장난감을 삼켰어요
#

# 산에서 야생동물을 만났어요 저를 공격할 것 같아요
# 엘리베이터가 갑자기 중간에 멈췄어요
# 엘리베이터가 갑자기 중간에 멈췄어요
# 말벌에게 쏘였어요
# 사람이 갑자기 쓰러졌어요
# 산에서 뱀에게 물렸어요
# 사람이 무거운 물건에 깔렸어요
# 해안가에 상어가 나타났어요
# 해안가에 상어가 나타났어요
# 집에 도둑강도이 들어왔어요
# 집에 불이 났어요
# 강풍
# 사람이 갑자기 쓰러졌어요
# 어디선가 연기가 나요 불이 나고 있는 것 같아요
# 어디선가 연기가 나요 불이 나고 있는 것 같아요
# 진통제
# 어떤 사람이 저를 죽이려고 해요
# 진통제
# 아이를 모르는 사람이 데려갔어요
# 의사
# 빨리 도와주세요
# 빨리 와주세요
# 빨리 와주세요
# 아들이 놀이터에서 놀다가 팔이 부러졌어요
# 아들이 놀이터에서 놀다가 팔이 부러졌어요
# 끓는물
# 음식을 하다가 손가락을 칼에 베였어요
# 아기를 낳을것 같아요
# 아기를 낳을것 같아요
# 엘리베이터
# 내가 방에 갇혔어요
# 반점생기다
# 세브란스 병원 진료 예약을 해주세요
# 어떤 사람이 자살을 시도하고 있어요
# 어떤 사람이 자살을 시도하고 있어요
# 아이가 방에 갇혔어요
# 아이가 말벌에 쏘여서 기절했어요
# 산에서 야생동물을 만났어요 저를 공격할 심해요
# 남편이 높은데서 떨어져서 머리에서 피나요
# 아이가 장난감을 삼켰어요
# 아이가 장난감을 삼켰어요
# 장단지
# 발목을 접질렀어요
# 장난감
# 동생이 문틈에 손이 끼었어요
# 아이가 방에 갇혔어요
# 아이가 방에 갇혔어요
# 술 취한 사람이 방망이로 사람들을 때리고 있어요
# 술 취한 사람이 방망이로 사람들을 때리고 있어요
# 은평구
# 친구가 숨을 안 쉬는 것 같아요
# 의사
# 도와주세요 !
# 탈골
# 고속도로에서 자동차가 갑자기 멈췄어요
# 진통제
# 어떤 사람이 칼에 찔려서 피를 많이 흘리고 있어요
# 산에서 야생동물을 만났어요 넘어져서 못 일어나겠어요
# 스키를 타다가 넘어져서 못 일어나겠어요
# 아파트
# 무릎 인대를 다친 것 같아요
# 아기를 낳을것 같아요
# 집 벽이 무너질려고 해요
# 의사
# 감전 사고가 났어요
# 진통제
# 어떤 사람이 칼로 위협하고 있어요
# 끓는물
# 음식을 하다가 손가락을 칼에 베였어요
# 가스가 새고 있는 것 같아요
# 가스가 새고 있는 것 같아요
# 어떤 사람이 자살을 시도하고 있어요
# 어떤 사람이 칼에 찔려서 피를 많이 흘리고 있어요
# 아이를 공원에서 잃어버렸어요
# 차 안에 강아지가 방치되어있어요
# 성동구
# 고압선이 끊어져 있어요
# 진통제
# 사람이 갑자기 쓰러졌어요
# 체온계
# 몸에 열이 많이 나고 두통이 심해요
# 성동구
# 집에 전기가 나갔어요
# 어떤 사람이 무기흉기를 소지하고 있어요
# 어떤 사람이 무기흉기를 소지하고 있어요
# 학생
# 광견병에 걸린 개에게 물렸어요
# 유리가 깨져서 발을 다쳤어요
# 유리가 깨져서 발을 다쳤어요
# 알려주세요
# 유리가 깨져서 발을 다쳤어요
# 보내주세요구급차
# 엄마가 신장병에 있는데 쓰러지셨어요
# 밖에 모르는 사람이 서성거려요
# 밖에 모르는 사람이 서성거려요
# 질식
# 어떤 사람이 건물에서 추락했어요
# 의사
# 아내가 쓰러졌어요
# 아파트
# 무릎 인대를 다친 것 같아요
# 성북구
# 문에 몸이 끼었어요
# 2
# 근처에서 폭탄이 터졌어요
# 공원
# 밖에 모르는 사람이 서성거려요
# 성동구
# 문에 몸이 끼었어요
# 독극물
# 비행기가 추락하고 있어요
# 경찰
# 눈에 이물질이 들어갔어요
# 아기를 낳을것 같아요
# 가스가 새고 있는 것 같아요
# 아내가 쓰러졌어요
# 아내가 쓰러졌어요
# 62
# 너무 아파요
# 산에서 야생동물을 만났어요 저를 공격할 것 같아요
# 강도가 들어온것 같아요
# 통학버스
# 근처에 있는 건물이 붕괴되고 있어요
# 진통제
# 무릎 인대를 다친 것 같아요
# 친구가 음식을 먹다가 실수로 방부제를 같이 먹었어요
# 친구가 음식을 먹다가 실수로 방부제를 같이 먹었어요
# 누전
# 폭탄이 터졌어요
# 통학버스
# 근처에 있는 건물이 붕괴되고 있어요
# 말벌에게 쏘였어요
# 아이가 말벌에 쏘여서 기절했어요
# 엘리베이터
# 밖에 싸움이 났어요 경찰을 불러주세요
# 앞집
# 옆집에 불이 났어요
# 비상약
# 어떤 사람이 길거리에서 피를 많이 흘리고 있어요
# 의사
# 도와주세요 !
# 강북구
# 해파리에게 쏘였어요
# 아이가 말벌에 쏘여서 기절했어요
# 아이가 말벌에 쏘여서 기절했어요
# 아내가 쓰러졌어요
# 친구가 숨을 안 쉬는 것 같아요
# 음식물
# 음식을 하다가 손가락을 칼에 베였어요
# 반점생기다
# 세브란스 병원 진료 예약을 해주세요
# 해안가에 상어가 나타났어요
# 이상한 사람이 저를 쫓아와요
# 기절하다
# 광견병에 걸린 개에게 물렸어요
# 반점생기다
# 세브란스 병원 진료 예약을 해주세요
# 보내주세요구급차
# 이상한 사람이 저를 쫓아와요
# 중랑구
# 지하철 역 안에서 화재가 발생했어요
# 집에 불이 났어요
# 집에 불이 났어요
# 산에서 야생동물을 만났어요 붕괴되고
# 집에 불이 났어요
# 보내주세요구급차
# 할머니가 갑자기 쓰러지셨어요
# 엘리베이터
# 차 안에 강아지가 방치되어있어요
# 가스가 새고 있는 것 같아요
# 가스가 새고 있어요
# 고압전선
# 근처에서 폭탄이 터졌어요
# 소화기
# 밖에 불이 났어요 소방차를 불러주세요
# 독사
# 독버섯을 먹은 것 같아요
# 아이를 공원에서 잃어버렸어요
# 아이를 공원에서 잃어버렸어요
# 의사
# 내가 방에 갇혔어요
# 해안가에 상어가 나타났어요
# 눈에 이물질이 들어갔어요
# 말벌에게 쏘였어요
# 엄마가 신장병에 있는데 쓰러지셨어요
# 아이가 장난감을 삼켰어요
# 아이가 장난감을 삼켰어요
# 왼쪽-눈
# 문에 몸이 끼었어요
# 파편
# 가스가 새고 있는 것 같아요
# 운동장
# 아이가 독극물을 삼켰어요
# 술 취한 사람이 방망이로 사람들을 때리고 있어요
# 술 취한 사람이 방망이로 사람들을 때리고 있어요
# 운동장
# 아기가 숨을 안 쉬어요
# 빨리 와주세요
# 강아지가 뼈를 삼켰어요
# 어떤 사람이 바다에 빠졌어요
# 어떤 사람이 바다에 빠졌어요
# 산에서 뱀에게 물렸어요
# 친구가 숨을 안 쉬는 것 같아요
# 경찰
# 비행기가 추락하고 있어요
# 오른쪽
# 허리가 아파서 일어날 수 없어요
# 아이가 낳을것 같아요
# 아이가 독극물을 삼켰어요
# 말벌에게 쏘였어요
# 말벌에게 쏘였어요
# 술 취한 사람이 방망이로 사람들을 때리고 있어요
# 할머니가 갑자기 쓰러지셨어요
# 폭우
# 홍수가 나서 집이 물에 잠기고 있어요
# 몸에 열이 많이 나고 두통이 심해요
# 몸에 열이 많이 나고 두통이 심해요
# 아이를 모르는 사람이 데려갔어요
# 아이를 모르는 사람이 데려갔어요
# 의사
# 지하철 역 안에서 화재가 발생했어요
# 보내주세요구급차
# 119 구조대를 불러주세요
# 허리가 아파서 일어날 수 없어요
# 어떤 사람이 길거리에서 피를 많이 흘리고 있어요
# 알려주세요
# 윗집에 불이 났어요
# 산에서 야생동물을 만났어요 저를 공격할 것 같아요
# 주변 구조물이 무너져서 몸이 끼었어요 몸을 움직이지 못하겠어요
# 말려주세요
# 동생이 문틈에 손이 끼었어요
# 산에서 뱀에게 물렸어요
# 친구가 감전 사고를 당했어요
# 16
# 너무 아파요
# 연기
# 눈에 이물질이 들어갔어요
# 보내주세요구급차
# 급류에 친구가 휩쓸렸어요
# 보내주세요구급차
# 할머니가 갑자기 쓰러지셨어요
# 유리가 깨져서 발을 다쳤어요
# 강도가 들어온것 같아요
# 산에서 야생동물을 만났어요 저를 공격할 것 같아요
# 남편이 높은데서 떨어져서 머리에서 피나요
# 딸
# 복통이 심해요
# 연기
# 112에 신고해주세요
# 아이가 말벌에 쏘여서 기절했어요
# 아이가 말벌에 쏘여서 기절했어요
# 발목
# 발목을 접질렀어요
# 말벌에게 쏘였어요
# 어지러워서 서있을 수 없어요
# 약국
# 밖에 불이 났어요 소방차를 불러주세요
# 아이가 장난감을 삼켰어요
# 아기가 장난감을 사켰어요
# 알려주세요
# 윗집에 불이 났어요
# 45
# 어떤 사람이 길거리에서 피를 많이 흘리고 있어요
# 마포구
# 배가 침몰하고 있어요
# 산에서 야생동물을 만났어요 저를 공격할 것 같아요
# 강도가 들어온것 같아요
# 아이가 장난감을 삼켰어요
# 아기가 장난감을 사켰어요
# 질식
# 어떤 사람이 벼락을 맞았어요
# 깔리다
# 근처에 있는 건물이 붕괴되고 있어요
# 중랑구
# 배가 침몰하고 있어요
# 딸
# 복통이 심해요
# 말벌에게 쏘였어요
# 쫓아오는 것 같아요
# Epoch: 01 | Time: 2m 57s
# 	 Train Loss: 0.126 | Train PPL:   1.134
# 	 Val Loss: 0.730 | Val PPL:   2.075
# 	 Val BLEU :  0.000 | Val Accuracy :  0.000
# 절단
# 신체부위가 절단됐어요
# 집에 불이 났어요
# 아랫집에 불이 났어요
# 독버섯을 먹은 것 같아요
# 독버섯을 먹은 것 같아요
# 근처에서 폭탄이 터졌어요
# 근처에서 폭탄이 터졌어요
# 급류에 친구가 휩쓸렸어요
# 급류에 친구가 휩쓸렸어요
# 장난감
# 문에 몸이 끼었어요
# 아기가 갑자기 토해요
# 아기가 갑자기 토해요
# 장난감
# 어떤 사람이 바다에 빠졌어요
# 절단
# 신체부위가 절단됐어요
# 빌라
# 집에 도둑강도이 들어왔어요
# 동대문구
# 문에 몸이 끼었어요
# 골절
# 고속도로에서 자동차가 갑자기 멈췄어요
# 성동구
# 고압선이 끊어져 있어요
# 근처에서 폭탄이 터졌어요
# 근처에서 폭탄이 터졌어요
# 옆집 할아버지
# 여기 서대문구 홍제동 한양아파트인데 옥상에서 사람이 떨어지려고해요
# 숨을안쉬다
# 숨이 안 쉬어져요
# 아이가 방에 갇혔어요
# 터널이 무너져 갇혔어요
# 발작
# 사람이 갑자기 쓰러졌어요
# 절단
# 친구가 음식을 먹다가 실수로 방부제를 같이 먹었어요
# 옆집
# 집이 흔들려요
# 할아버지
# 비행기가 추락하고 있어요
# 아이가 말벌에 쏘여서 기절했어요
# 아이가 말벌에 쏘여서 기절했어요
# 바다에서 조난을 당했어요
# 바다에서 조난을 당했어요
# 어떤 사람이 교통사고를 당했어요
# 어떤 사람이 칼로 위협하고 있어요
# 119
# 어지러워서 서있을 수 없어요
# 우리아이가 갑자기 의식을 잃었어요
# 우리아이가 갑자기 의식을 잃었어요
# 사람이 갑자기 쓰러졌어요
# 어떤 사람이 자살을 시도하고 있어요
# 고속도로
# 해파리에게 쏘였어요
# 사람이 갑자기 쓰러지셨어요
# 할머니가 갑자기 쓰러지셨어요
# 아이가 방에 갇혔어요
# 아이를 공원에서 잃어버렸어요
# 식사를 하다가 목에 음식이 걸렸어요
# 식사를 하다가 목에 음식이 걸렸어요
# 엽총
# 내가 방에 갇혔어요
# 이상한 사람이 저를 쫓아와요
# 이상한 사람이 저를 쫓아와요
# 옆집
# 집이 흔들려요
# 윗집사람
# 윗집에 불이 났어요
# 남편이 높은데서 떨어져서 머리에서 피나요
# 남편이 높은데서 떨어져서 머리에서 피나요
# 남학생
# 어떤 사람이 벼락을 맞았어요
# 가스가 새고 있는 것 같아요
# 가스가 새고 있는 것 같아요
# 가스가 새고 있는 것 같아요
# 가스가 새고 있는 것 같아요
# 가스가 새고 있는 것 같아요
# 가스가 새고 있는 것 같아요
# 119
# 급류에 친구가 휩쓸렸어요
# 몸이 결박
# 감전 사고가 났어요
# 아이가 독극물을 삼켰어요
# 아이가 독극물을 삼켰어요
# 배
# 복통이 심해요
# 빨리 도와주세요
# 빨리 도와주세요
# 아기가 숨을 안 쉬어요
# 아기가 숨을 안 쉬어요
# 부엌
# 세브란스 병원 진료 예약을 해주세요
# 유리
# 도와주세요 !
# 체온계
# 주변 구조물이 무너져서 몸이 끼었어요 몸을 움직이지 못하겠어요
# 밖에 싸움이 났어요
# 밖에 싸움이 났어요 경찰을 불러주세요
# 화약
# 집에 도둑강도이 들어왔어요
# 어떤 사람이 집단폭력을 당하고 있어요
# 어떤 사람한테 납치당했어요
# 해안가에 상어가 나타났어요
# 해안가에 해파리가 나타났어요
# 아기가 갑자기 토해요
# 아기가 숨을 안 쉬어요
# 가스가 새고 있는 것 같아요
# 가스가 새고 있는 것 같아요
# 장단지
# 차 안에 강아지가 방치되어있어요
# 가스가 새고 있는 것 같아요
# 무릎 인대를 다친 것 같아요
# 유리
# 배가 침몰하고 있어요
# 유리
# 지하철 역 안에서 화재가 발생했어요
# 윗집사람
# 집에 도둑강도이 들어왔어요
# 창문
# 옆집에 불이 났어요
# 몸이 결박 당해있어요
# 몸이 결박 당해있어요
# 고속도로에서 음식을 먹다가 멈췄어요
# 고속도로에서 자동차가 갑자기 멈췄어요
# 아이가 말벌에 쏘여서 기절했어요
# 아이가 말벌에 쏘여서 기절했어요
# 집단폭행
# 산에서 뱀에게 물렸어요
# 옆집 숨을 안 쉬는 것 같아요
# 스키를 타다가 넘어져서 못 일어나겠어요
# 어지러움
# 광견병에 걸린 개에게 물렸어요
# 체온계
# 주변 구조물이 무너져서 몸이 끼었어요 몸을 움직이지 못하겠어요
# 사람이 갑자기 쓰러졌어요
# 엄마가 신장병에 있는데 쓰러지셨어요
# 절단
# 신체부위가 절단됐어요
# 여기 서대문구 홍제동 한양아파트인데 옥상에서 사람이 떨어지려고해요
# 여기 서대문구 홍제동 한양아파트인데 옥상에서 사람이 떨어지려고해요
# 산에서 야생동물을 만났어요 저를 공격할 것 같아요
# 산에서 야생동물을 만났어요 저를 공격할 것 같아요
# 아이가 장난감을 삼켰어요
# 아이가 장난감을 삼켰어요
# 해독제
# 아이를 모르는 사람이 데려갔어요
# 어떤 사람이 칼에 찔려서 피를 많이 흘리고 있어요
# 어떤 사람이 칼에 찔려서 피를 많이 흘리고 있어요
# 어떤 사람이 무기흉기를 소지하고 있어요
# 어떤 사람이 무기흉기를 소지하고 있어요
# 화약
# 사람이 무거운 물건에 깔렸어요
# 집단폭행
# 근처에 있는 건물이 붕괴되고 있어요
# 서울시
# 숨이 안 쉬어져요
# 집단폭행
# 산에서 뱀에게 물렸어요
# 체온계
# 산에서 야생동물을 만났어요 저를 공격할 것 같아요
# 아이가 장난감을 삼켰어요
# 아이가 장난감을 삼켰어요
# 화약
# 터널이 무너져 갇혔어요
# 알려주세요
# 아랫집에 불이 났어요
# 아이가 방에 갇혔어요
# 아이를 공원에서 잃어버렸어요
# 발작
# 광견병에 걸린 개에게 물렸어요
# 옆집 야생동물을 만났어요 저를 공격할 것 같아요
# 산에서 야생동물을 만났어요 저를 공격할 것 같아요
# 볼
# 어떤 사람이 칼로 위협하고 있어요
# 옥상
# 윗집에 불이 났어요
# 멧돼지
# 어떤 사람이 교통사고를 당했어요
# 알려주세요
# 우리 집에 불이 났어요
# 숨을안쉬다
# 숨이 안 쉬어져요
# 화상
# 독버섯을 먹은 것 같아요
# 광견병에 걸린 개에게 물렸어요
# 어떤 사람이 벼락을 맞았어요
# 장단지
# 발목을 접질렀어요
# 우리집
# 우리 집에 불이 났어요
# 강
# 급류에 친구가 휩쓸렸어요
# 화상
# 화상을 입었어요
# 강아지가 뼈를 삼켰어요
# 강아지가 뼈를 삼켰어요
# 몸이 결박 당해있어요
# 몸이 결박 당해있어요
# 유리가 깨져서 발을 다쳤어요
# 강도가 들어온것 같아요
# 아이가 말벌에 쏘여서 기절했어요
# 아이가 말벌에 쏘여서 기절했어요
# 빌라
# 아랫집에 불이 났어요
# 무릎
# 무릎 인대를 다친 것 같아요
# 어떤 사람이 저를 죽이려고 해요
# 어떤 사람이 저를 죽이려고 해요
# 이물질
# 남편이 높은데서 떨어져서 머리에서 피나요
# 112에 신고해주세요
# 112에 신고해주세요
# 아기가 숨을 안 쉬어요
# 아기가 숨을 안 쉬어요
# 어떤 사람이 무기흉기를 소지하고 있어요
# 어떤 사람이 무기흉기를 소지하고 있어요
# 어떤 사람이 교통사고를 당했어요
# 어떤 사람이 교통사고를 당했어요
# 몸이 결박 당해있어요
# 몸이 결박 당해있어요
# 가스가 새고 있어요
# 가스가 새고 있어요
# 왼쪽
# 고속도로에서 자동차가 갑자기 멈췄어요
# 연기
# 어디선가 연기가 나요 불이 나고 있는 것 같아요
# 해안가에 상어가 나타났어요
# 해안가에 해파리가 나타났어요
# 발목
# 집에 모르는 사람이 침입했어요
# 어떤 사람이 교통사고를 당했어요
# 근처에서 폭탄이 터졌어요
# 몸이 결박
# 내가 방에 갇혔어요
# 쫓아오는 것 같아요
# 쫓아오는 것 같아요
# 몸이 몸이 끼었어요
# 산에서 뱀에게 물렸어요
# 창문
# 지하철 역 안에서 화재가 발생했어요
# 밖에 싸움이 났어요 경찰을 불러주세요
# 밖에 싸움이 났어요 경찰을 불러주세요
# 해안가에 상어가 나타났어요
# 숨이 안 쉬어져요
# 낫
# 아파서 못 참을것 같아요
# 119
# 119 구조대를 불러주세요
# 말벌에게 쏘였어요
# 말벌에게 쏘였어요
# 유리
# 도와주세요 !
# 아이가 장난감을 삼켰어요
# 아이가 독극물을 삼켰어요
# 붕괴
# 고압선이 끊어져 있어요
# 유리
# 산에서 뱀에게 물렸어요
# 아기가 숨을 안 쉬어요
# 아기가 숨을 안 쉬어요
# 차 안에 강아지가 방치되어있어요
# 차 안에 강아지가 방치되어있어요
# 아기가 장난감을 삼켰어요
# 아이가 장난감을 삼켰어요
# 95
# 숨이 안 쉬어져요
# 여기 서대문구 홍제동 한양아파트인데 옥상에서 사람이 떨어지려고해요
# 여기 서대문구 홍제동 한양아파트인데 옥상에서 사람이 떨어지려고해요
# 홍수가 나서 집이 물에 잠기고 있어요
# 홍수가 나서 집이 물에 잠기고 있어요
# 출혈
# 급류에 친구가 휩쓸렸어요
# 어떤 사람이 무기흉기를 소지하고 있어요
# 어떤 사람이 칼로 위협하고 있어요
# 구급대원
# 친구가 감전 사고를 당했어요
# 화약
# 터널이 무너져 갇혔어요
# 강풍
# 어떤 사람이 집단폭력을 당하고 있어요
# 남학생
# 어떤 사람이 벼락을 맞았어요
# 빌라
# 아랫집에 불이 났어요
# 밖에 싸움이 났어요 소방차를 불러주세요
# 밖에 불이 났어요 소방차를 불러주세요
# 복통이 심해요
# 복통이 심해요
# 발목
# 발목을 접질렀어요
# 발작
# 광견병에 걸린 개에게 물렸어요
# 급류에 친구가 휩쓸렸어요
# 급류에 친구가 휩쓸렸어요
# 해안가에 상어가 나타났어요
# 숨이 안 쉬어져요
# 발목
# 발목을 접질렀어요
# 파편
# 무릎 인대를 다친 것 같아요
# 절단
# 신체부위가 절단됐어요
# 말벌
# 해안가에 상어가 나타났어요
# 빨리 와주세요
# 빨리 와주세요
# 유리
# 도와주세요 !
# 어떤 사람이 저를 죽이려고 해요
# 어떤 사람이 저를 죽이려고 해요
# 해안가에 상어가 나타났어요
# 해안가에 해파리가 나타났어요
# 강
# 급류에 친구가 휩쓸렸어요
# 홍수가 나서 집이 물에 잠기고 있어요
# 홍수가 나서 집이 물에 잠기고 있어요
# 허벅지
# 복통이 심해요
# 광견병에 걸린 개에게 물렸어요
# 사람이 갑자기 쓰러졌어요
# 폭탄이 터졌어요
# 폭탄이 터졌어요
# 사람이 쏘였어요
# 어떤 사람이 집단폭력을 당하고 있어요
# 아이가 방에 갇혔어요
# 아이를 공원에서 잃어버렸어요
# 음식을 하다가 손가락을 칼에 베였어요
# 음식을 하다가 손가락을 칼에 베였어요
# 배
# 복통이 심해요
# 지혈대
# 해파리에게 쏘였어요
# 고열
# 친구가 감전 사고를 당했어요
# 아들이 놀이터에서 놀다가 팔이 부러졌어요
# 아들이 놀이터에서 놀다가 팔이 부러졌어요
# 폭탄이 터졌어요
# 근처에서 폭탄이 터졌어요
# 화약
# 사람이 무거운 물건에 깔렸어요
# 집 벽이 무너질려고 해요
# 집 벽이 무너질려고 해요
# 집 벽이 무너질려고 해요
# 가스가 새고 있는 것 같아요
# 몸이 결박 떨어져서 머리에서 피나요
# 아내가 쓰러졌어요
# 말벌
# 말벌에게 쏘였어요
# 95
# 숨이 안 쉬어져요
# 옆집 할아버지
# 강도가 들어온것 같아요
# 선반
# 집에 전기가 나갔어요
# 가스가 새고 있어요
# 가스가 새고 있어요
# 어떤 사람이 길거리에서 피를 많이 흘리고 있어요
# 어떤 사람이 길거리에서 피를 많이 흘리고 있어요
# 선반
# 폭탄이 터졌어요
# 끓는물
# 음식을 하다가 손가락을 칼에 베였어요
# 아이가 방에 갇혔어요
# 아이를 공원에서 잃어버렸어요
# 여기 서대문구 홍제동 한양아파트인데 옥상에서 사람이 떨어지려고해요
# 어떤 사람이 길거리에서 피를 많이 흘리고 있어요
# 화상
# 친구가 음식을 먹다가 실수로 방부제를 같이 먹었어요
# 남편이 높은데서 떨어져서 머리에서 피나요
# 스키를 타다가 넘어져서 못 일어나겠어요
# 유리
# 지하철 역 안에서 화재가 발생했어요
# 이물질
# 어떤 사람이 길거리에서 피를 많이 흘리고 있어요
# 빌라
# 집에 불이 났어요
# 붕괴
# 우리아이가 갑자기 의식을 잃었어요
# 눈에 이물질이 들어갔어요
# 눈에 이물질이 들어갔어요
# 몸이 결박 당해있어요
# 내가 방에 갇혔어요
# 화상을 입었어요
# 화상을 입었어요
# 아이가 독극물을 삼켰어요
# 아이가 독극물을 삼켰어요
# 119
# 119 구조대를 불러주세요
# 성동구
# 폭탄이 터졌어요
# 동대문구
# 문에 몸이 끼었어요
# 집 벽이 무너질려고 해요
# 집 벽이 무너질려고 해요
# 감전 사고가 났어요
# 감전 사고가 났어요
# 몸이 결박 당해있어요
# 몸이 결박 당해있어요
# 홍수가 나서 집이 물에 잠기고 있어요
# 아이를 모르는 사람이 데려갔어요
# 열어주세요
# 집이 흔들려요
# 독버섯을 먹은 것 같아요
# 독버섯을 먹은 것 같아요
# 몸이 몸이 끼었어요
# 산에서 뱀에게 물렸어요
# 아이가 장난감을 삼켰어요
# 아기가 장난감을 사켰어요
# 약국
# 밖에 모르는 사람이 서성거려요
# 열나다
# 할머니가 갑자기 쓰러지셨어요
# 어떤 사람이 무기흉기를 소지하고 있어요
# 어떤 사람이 무기흉기를 소지하고 있어요
# 어떤 사람이 저를 죽이려고 해요
# 어떤 사람이 저를 죽이려고 해요
# 집 벽이 무너질려고 해요
# 집 벽이 무너질려고 해요
# 엘리베이터가 갑자기 중간에 멈췄어요
# 엘리베이터가 갑자기 중간에 멈췄어요
# 어떤 사람이 교통사고를 당했어요
# 어떤 사람이 건물에서 추락했어요
# 창문
# 집이 흔들려요
# 사람이 쏘였어요
# 어떤 사람이 집단폭력을 당하고 있어요
# 홍수가 나서 집이 물에 잠기고 있어요
# 홍수가 나서 집이 물에 잠기고 있어요
# 옆집
# 집이 흔들려요
# 유리가 깨져서 발을 다쳤어요
# 주변 구조물이 무너져서 몸이 끼었어요 몸을 움직이지 못하겠어요
# 멧돼지
# 어떤 사람이 바다에 빠졌어요
# 어떤 사람이 교통사고를 당했어요
# 어떤 사람이 교통사고를 당했어요
# 유리
# 도와주세요 !
# 유리
# 배가 침몰하고 있어요
# 남학생
# 어떤 사람이 벼락을 맞았어요
# 아이가 말벌에 쏘여서 기절했어요
# 아이가 말벌에 쏘여서 기절했어요
# 88
# 너무 아파요

# %% [markdown]
# ## Test code

# %%
# example_idx = 10

src = X_test[0].reshape(-1, 227, 246).cuda().float() # 인덱스 번호 넣기
trg = target[900] # 인덱스 번호 넣기

# src = vars(test_dataset.examples[example_idx])['src']
# trg = vars(test_dataset.examples[example_idx])['trg']

print(f'소스 문장: {src}')
print(f'타겟 문장: {trg}')
print("모델 출력 결과:", " ".join(translate_SL(src, word_to_index, model, device)))
